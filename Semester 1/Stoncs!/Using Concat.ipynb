# %%
import pandas as pd
import seaborn as sns
import numpy as np
import requests
data1 = pd.read_json('gme.json')
data1.head()
# Out:
#         Date     Open     High      Low    Close  Adj Close    Volume
# 0 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691666  76216000
# 1 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683250  11021600
# 2 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 3 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 4 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
data2 = pd.read_json('recentGME.json')
data2.head()
# Out:
#         Date   Open   High    Low  Close     Volume
# 0 2024-05-14  64.83  64.83  36.00  48.75  206973629
# 1 2024-05-15  40.31  42.35  31.00  39.55  131776493
# 2 2024-05-16  33.98  35.24  27.59  27.67   76159605
# 3 2024-05-17  21.86  22.41  19.70  22.21   96046070
# 4 2024-05-20  21.54  23.40  18.94  23.14   55261216

# %%
pd.concat([data1, data2])
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2002-02-13   2.40625   2.51500   2.38125   2.51250   1.691666  76216000
# 1  2002-02-14   2.54375   2.54875   2.48125   2.50000   1.683250  11021600
# 2  2002-02-15   2.50000   2.50625   2.46250   2.48750   1.674834   8389600
# 3  2002-02-19   2.47500   2.47500   2.34375   2.38750   1.607504   7410400
# 4  2002-02-20   2.40000   2.46875   2.38125   2.46875   1.662210   6892800
# ..        ...       ...       ...       ...       ...        ...       ...
# 89 2024-09-20  19.63000  22.03000  19.48200  21.85000        NaN  60804837
# 90 2024-09-23  21.54000  22.56000  21.23010  22.31000        NaN  13945783
# 91 2024-09-24  22.61000  22.72000  21.54000  22.63000        NaN  12112487
# 92 2024-09-25  22.16000  22.83000  22.06500  22.18000        NaN   6137420
# 93 2024-09-26  22.40000  22.64000  21.87000  22.29000        NaN   5771976
#
# [5694 rows x 7 columns]

# %%
data1.drop(["Adj Close"], inplace=True, axis=1)

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AMC&interval=5min&apikey=FYC9KS8S2M95VM5R'
r = requests.get(url)
data_amc = r.json()

print(data_amc)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'AMC', '3. Last Refreshed': '2024-09-30 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2024-09-30 19:55:00': {'1. open': '4.5700', '2. high': '4.5800', '3. low': '4.5506', '4. close': '4.5700', '5. volume': '2600'}, '2024-09-30 19:50:00': {'1. open': '4.5500', '2. high': '4.5690', '3. low': '4.5500', '4. close': '4.5500', '5. volume': '249'}, '2024-09-30 19:45:00': {'1. open': '4.5599', '2. high': '4.5700', '3. low': '4.5500', '4. close': '4.5500', '5. volume': '10313'}, '2024-09-30 19:40:00': {'1. open': '4.5500', '2. high': '4.5650', '3. low': '4.5500', '4. close': '4.5600', '5. volume': '2702'}, '2024-09-30 19:35:00': {'1. open': '4.5598', '2. high': '4.5600', '3. low': '4.5500', '4. close': '4.5600', '5. volume': '25272'}, '2024-09-30 19:30:00': {'1. open': '4.5550', '2. high': '4.5600', '3. low': '4.5500'
# ...

# %%
if "Time Series (5min)" in data_amc:
    time_series = data_amc["Time Series (5min)"]
    df = pd.DataFrame.from_dict(time_series, orient='index')
    df = df.astype(float)
    df.reset_index(drop=True, inplace=True)
    print(df)
else:
    print("Error fetching data:", data.get("Error Message", "Unknown error"))
# Out:
#     1. open  2. high  3. low  4. close  5. volume
# 0    4.5700   4.5800  4.5506    4.5700     2600.0
# 1    4.5500   4.5690  4.5500    4.5500      249.0
# 2    4.5599   4.5700  4.5500    4.5500    10313.0
# 3    4.5500   4.5650  4.5500    4.5600     2702.0
# 4    4.5598   4.5600  4.5500    4.5600    25272.0
# ..      ...      ...     ...       ...        ...
# 95   4.5300   4.5399  4.5201    4.5301    22115.0
# 96   4.5201   4.5300  4.5200    4.5202    12785.0
# 97   4.5250   4.5300  4.5200    4.5250    21216.0
# 98   4.5300   4.5300  4.5209    4.5297    41344.0
# 99   4.5170   4.5300  4.5101    4.5250    48110.0
#
# [100 rows x 5 columns]

# %%
combined_df = pd.concat([data1, data_amc], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19804\1730726616.py in <module>
# ----> 1 combined_df = pd.concat([data1, data_amc], ignore_index=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# ...

# %%
data_csv = pd.read_csv('amc.csv')
data_csv.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2013-12-18  19.180000  19.790001  18.900000  18.900000  13.593410  5457200
# 1  2013-12-19  18.900000  19.490000  18.809999  19.490000  14.017754  1605400
# 2  2013-12-20  19.650000  19.770000  19.400000  19.680000  14.154409   737100
# 3  2013-12-23  19.790001  19.990000  19.500000  19.740000  14.197562   698100
# 4  2013-12-24  19.740000  19.820000  19.500000  19.530001  14.046528   213700
