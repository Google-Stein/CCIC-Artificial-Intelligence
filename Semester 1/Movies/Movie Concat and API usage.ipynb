# %%
import pandas as pd
import seaborn as sns
import requests
import matplotlib.pyplot as plt

# %%
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

nowPlaying = requests.get(url, headers=headers)
nowPlaying = nowPlaying.json()
now = pd.DataFrame(nowPlaying["results"])
now.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg              [27, 53]  1114513
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [878, 27, 35]   933260
# 2  False  /uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg          [35, 53, 28]   877817
# 3  False  /1H0l07FGCx3e9G0zLBGiIfHk9Zc.jpg          [18, 80, 53]   889737
# 4  False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
#
#   original_language       original_title  \
# 0                en        Speak No Evil
# 1                en        The Substance
# 2                en                Wolfs
# 3                en  Joker: Folie à Deux
# 4                en             The Crow
#
#                                             overview  popularity  \
# 0  When an American family is invited to spend th...    2281.291
# 1  A fading celebrity decides to use a black mark...    1595.704
# 2  Hired to cover up a high-profile crime, a fixe...    1693.793
# 3  While struggling with his dual identity, Arthu...    1372.519
# 4  Soulmates Eric and Shelly are brutally murdere...    1690.146
#
#                         poster_path release_date                title  video  \
# 0  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11        Speak No Evil  False
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07        The Substance  False
# 2  /vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg   2024-09-20                Wolfs  False
# 3  /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01  Joker: Folie à Deux  False
# 4  /58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg   2024-08-21             The Crow  False
#
#    vote_average  vote_count
# 0         7.350         502
# 1         7.300         230
# 2         6.594         376
# 3         5.836         434
# 4         5.446         484

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

popular = requests.get(url, headers=headers)
popular = popular.json()
nowPopular = pd.DataFrame(popular["results"])
nowPopular.head()
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg            [28, 35, 878]   533535
# 1  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]   519182
# 2  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg                 [27, 53]  1114513
# 3  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg            [878, 27, 35]   933260
# 4  False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 10751, 12, 35, 18]  1022789
#
#   original_language        original_title  \
# 0                en  Deadpool & Wolverine
# 1                en       Despicable Me 4
# 2                en         Speak No Evil
# 3                en         The Substance
# 4                en          Inside Out 2
#
#                                             overview  popularity  \
# 0  A listless Wade Wilson toils away in civilian ...    5099.804
# 1  Gru and Lucy and their girls—Margo, Edith and ...    2524.611
# 2  When an American family is invited to spend th...    2281.291
# 3  A fading celebrity decides to use a black mark...    1595.704
# 4  Teenager Riley's mind headquarters is undergoi...    1561.870
#
#                         poster_path release_date                 title  video  \
# 0  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24  Deadpool & Wolverine  False
# 1  /wWba3TaojhK7NdycRhoQpsG0FaH.jpg   2024-06-20       Despicable Me 4  False
# 2  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11         Speak No Evil  False
# 3  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07         The Substance  False
# 4  /vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg   2024-06-11          Inside Out 2  False
#
#    vote_average  vote_count
# 0         7.744        4027
# 1         7.145        1892
# 2         7.347         503
# 3         7.300         230
# 4         7.642        4159

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

topRated = requests.get(url, headers=headers)
topRated = topRated.json()
nowTopRated = pd.DataFrame(topRated["results"])
nowTopRated.head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg         [18, 80]  278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     165.409
# 1  Spanning the years 1945 to 1955, a chronicle o...     114.464
# 2  In the continuing saga of the Corleone crime f...      94.902
# 3  The true story of how businessman Oskar Schind...      99.779
# 4  The defense and the prosecution have rested an...      48.136
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
# 4  /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10              12 Angry Men
#
#    video  vote_average  vote_count
# 0  False         8.707       26906
# 1  False         8.691       20423
# 2  False         8.576       12317
# 3  False         8.565       15729
# 4  False         8.547        8545

# %%
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

upcoming = requests.get(url, headers=headers)
upcoming = upcoming.json()
nowUpcoming = pd.DataFrame(upcoming["results"])
nowUpcoming.head()
# Out:
#    adult                     backdrop_path                 genre_ids       id  \
# 0  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27, 35]   933260
# 1  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg              [18, 80, 53]   889737
# 2  False  /4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg          [16, 878, 10751]  1184918
# 3  False  /tAwfoDyKiYa4KQdUp3DTMrEs4En.jpg  [16, 878, 12, 10751, 28]   698687
# 4  False  /hdFIdXwS8FSN2wIsuotjW1mshI0.jpg       [16, 35, 12, 10751]   831815
#
#   original_language                                original_title  \
# 0                en                                 The Substance
# 1                en                           Joker: Folie à Deux
# 2                en                                The Wild Robot
# 3                en                              Transformers One
# 4                en  Saving Bikini Bottom: The Sandy Cheeks Movie
#
#                                             overview  popularity  \
# 0  A fading celebrity decides to use a black mark...    1595.704
# 1  While struggling with his dual identity, Arthu...    1372.519
# 2  After a shipwreck, an intelligent robot called...    1328.503
# 3  The untold origin story of Optimus Prime and M...     704.262
# 4  When Bikini Bottom is scooped from the ocean, ...     532.810
#
#                         poster_path release_date  \
# 0  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07
# 1  /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12
# 3  /qbkAqmmEIZfrCO8ZQAuIuVMlWoV.jpg   2024-09-11
# 4  /30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg   2024-10-18
#
#                                           title  video  vote_average  \
# 0                                 The Substance  False         7.335
# 1                           Joker: Folie à Deux  False         5.800
# 2                                The Wild Robot  False         8.000
# 3                              Transformers One  False         7.400
# 4  Saving Bikini Bottom: The Sandy Cheeks Movie  False         0.000
#
#    vote_count
# 0         231
# 1         445
# 2         111
# 3         119
# 4           0

# %%
ConDf = pd.concat([now, nowPopular, nowTopRated, nowUpcoming])

# %%
display(ConDf)
# Out:
#     adult                     backdrop_path             genre_ids       id  \
# 0   False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg              [27, 53]  1114513
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [878, 27, 35]   933260
# 2   False  /uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg          [35, 53, 28]   877817
# 3   False  /1H0l07FGCx3e9G0zLBGiIfHk9Zc.jpg          [18, 80, 53]   889737
# 4   False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# ..    ...                               ...                   ...      ...
# 15  False  /tCQfubckzzcuCbsGugkpLhfjS5z.jpg          [28, 53, 80]   970347
# 16  False  /jf1V00dZdNkVfEq7VPk8frrlELk.jpg            [27, 9648]   748230
# 17  False  /oBmwaZ3NVa3JyZnv1qCo0znxjUw.jpg          [27, 80, 53]  1029281
# 18  False  /AjTodtZJlQxycfRPktnUTpknblv.jpg   [16, 12, 35, 10751]  1207830
# 19  False  /t3LicFpYHeYpwqm7L5wDpd22hL5.jpg              [12, 14]      671
#
#    original_language                            original_title  \
# 0                 en                             Speak No Evil
# 1                 en                             The Substance
# 2                 en                                     Wolfs
# 3                 en                       Joker: Folie à Deux
# 4                 en                                  The Crow
# ..               ...                                       ...
# 15                en                                The Killer
# 16                en                               Salem's Lot
# 17                en                           Strange Darling
# 18                en        Gracie & Pedro: Pets to the Rescue
# 19                en  Harry Potter and the Philosopher's Stone
#
#                                              overview  popularity  \
# 0   When an American family is invited to spend th...    2281.291
# 1   A fading celebrity decides to use a black mark...    1595.704
# 2   Hired to cover up a high-profile crime, a fixe...    1693.793
# 3   While struggling with his dual identity, Arthu...    1372.519
# 4   Soulmates Eric and Shelly are brutally murdere...    1690.146
# ..                                                ...         ...
# 15  Zee is a feared contract killer known as "the ...     302.421
# 16  Author Ben Mears returns to his childhood home...     283.882
# 17  Nothing is what it seems when a twisted one-ni...     271.705
# 18  Family frenemies, Gracie and Pedro, must put t...     262.058
# 19  Harry Potter has lived under the stairs at his...     246.557
#
#                          poster_path release_date  \
# 0   /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11
# 1   /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07
# 2   /vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg   2024-09-20
# 3   /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01
# 4   /58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg   2024-08-21
# ..                               ...          ...
# 15  /6PCnxKZZIVRanWb710pNpYVkCSw.jpg   2024-08-22
# 16  /j7ncdqBVufydVzVtxmXu8Ago4ox.jpg   2024-10-03
# 17  /rhhE4U49hM50s7XCYZ8dHShhM7x.jpg   2024-08-22
# 18  /1agSI7NGvagr720za8XAubtqUoB.jpg   2024-05-01
# 19  /wuMc08IPKEatf9rnMNXvIDxqP4W.jpg   2001-11-16
#
#                                        title  video  vote_average  vote_count
# 0                              Speak No Evil  False         7.350         502
# 1                              The Substance  False         7.300         230
# 2                                      Wolfs  False         6.594         376
# 3                        Joker: Folie à Deux  False         5.836         434
# 4                                   The Crow  False         5.446         484
# ..                                       ...    ...           ...         ...
# 15                                The Killer  False         6.597         252
# 16                               Salem's Lot  False         6.366         138
# 17                           Strange Darling  False         7.011          88
# 18        Gracie & Pedro: Pets to the Rescue  False         7.273          11
# 19  Harry Potter and the Philosopher's Stone  False         7.914       27161
#
# [80 rows x 14 columns]

# %%
ConDf.drop_duplicates(subset=['id'], inplace=True)

# %%
ConDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              64 non-null     bool
#  1   backdrop_path      64 non-null     object
#  2   genre_ids          64 non-null     object
#  3   id                 64 non-null     int64
#  4   original_language  64 non-null     object
#  5   original_title     64 non-null     object
#  6   overview           64 non-null     object
#  7   popularity         64 non-null     float64
#  8   poster_path        64 non-null     object
#  9   release_date       64 non-null     object
#  10  title              64 non-null     object
#  11  video              64 non-null     bool
#  12  vote_average       64 non-null     float64
#  13  vote_count         64 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 6.6+ KB

# %%
def get_revenueBudget(df):
    '''uses the movie ID to get data from the "details" endpoint. Returns a dataframe of revenue and budget data.
    '''
    data = {
        "id": [], 
        "budget": [],
        "revenue": []
        
    }
    
    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        print(response)
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])

        
    return pd.DataFrame(data)

money = get_revenueBudget(ConDf)
print(ConDf.info())
# Out:
# {'adult': False, 'backdrop_path': '/9R9Za5kybgl5AhuCNoK3gngaBdG.jpg', 'belongs_to_collection': None, 'budget': 15000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://www.speaknoevilmovie.com', 'id': 1114513, 'imdb_id': 'tt27534307', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Speak No Evil', 'overview': 'When an American family is invited to spend the weekend at the idyllic country estate of a charming British family they befriended on vacation, what begins as a dream holiday soon warps into a snarled psychological nightmare.', 'popularity': 2281.291, 'poster_path': '/fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg', 'production_companies': [{'id': 3172, 'logo_path': '/rzKluDcRkIwHZK2pHsiT667A2Kw.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-11', 'revenue': 57652430, 'runtime': 110, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'Speak No Evil', 'video': False, 'vote_average': 7.344, 'vote_count': 506}
# {'adult': False, 'backdrop_path': '/7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg', 'belongs_to_collection': None, 'budget': 17500000, 'genres': [{'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://www.the-match-factory.com/catalogue/films/the-substance.html', 'id': 933260, 'imdb_id': 'tt17526714', 'origin_country': ['GB'], 'original_language': 'en', 'original_title': 'The Substance', 'overview': 'A fading celebrity decides to use a black market drug, a cell-replicating substance that temporarily creates a younger, better version of herself.', 'popularity': 1595.704, 'poster_path': '/lqoMzCcZYEFK729d6qzt349fB4o.jpg', 'production_companies': [{'id': 10163, 'logo_path': '/16KWBMmfPX0aJzDExDrPxSLj0Pg.png', 'name': 'Working Title Films', 'origin_country': 'GB'}, {'id': 233939, 'logo_path': None, 'name': 'Blacksmith', 'origin_country': 'FR'}], 'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-07', 'revenue': 10492678, 'runtime': 141, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'If you follow the instructions, what could go wrong?', 'title': 'The Substance', 'video': False, 'vote_average': 7.3, 'vote_count': 230}
# {'adult': False, 'backdrop_path': '/uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg', 'belongs_to_collection': {'id': 1326786, 'name': 'Wolfs Collection', 'poster_path': '/i07rSqX1ovPUxsDIfSdares5Iia.jpg', 'backdrop_path': '/1kfIIYMhnCC6JTq9M4Zxz62YXfs.jpg'}, 'budget': 0, 'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'name': 'Thriller'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://tv.apple.com/movie/umc.cmc.c3xhu25rw4jxxxzq4oio6snu', 'id': 877817, 'imdb_id': 'tt14257582', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Wolfs', 'overview': "Hired to cover up a high-profile crime, a fixer soon finds his night spiralling out of control when he's forced to work with an unexpected counterpart.", 'popularity': 1693.793, 'poster_path': '/vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg', 'production_companies': [{'id': 1782, 'logo_path': '/d1mlUfuG0NoQ4x0C7bK80wLGWA1.png', 'name': 'Smoke House Pictures', 'origin_country': 'US'}, {'id': 81, 'logo_path': '/8wOfUhA7vwU2gbPjQy7Vv3EiF0o.png', 'name': 'Plan B Entertainment', 'origin_country': 'US'}, {'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5EH3fpCp68vvB.png', 'name': 'Apple Studios', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-20', 'revenue': 0, 'runtime': 108, 'spoken_languages': [{'english_name': 'Croatian', 'iso_639_1': 'hr', 'name': 'Hrvatski'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': "They're not partners. They're not friends. They're wolfs.", 'title': 'Wolfs', 'video': False, 'vote_average': 6.591, 'vote_count': 378}
# {'adult': False, 'backdrop_path': '/1H0l07FGCx3e9G0zLBGiIfHk9Zc.jpg', 'belongs_to_collection': {'id': 987044, 'name': 'Joker Collection', 'poster_path': '/jmopX21dlCinxmzd8KLOBFeN2P9.jpg', 'backdrop_path': '/k1YC7mFLvxX4bbD7P8lkcML0Jek.jpg'}, 'budget': 195000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://www.joker.movie', 'id': 889737, 'imdb_id': 'tt11315808', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Joker: Folie à Deux', 'overview': "While struggling with his dual identity, Arthur Fleck not only stumbles upon true love, but also finds the music that's always been inside him.", 'popularity': 1372.519, 'poster_path': '/if8QiqCI7WAGImKcJCfzp6VTyKA.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 83036, 'logo_path': None, 'name': 'Joint Effort', 'origin_country': 'US'}, {'id': 216687, 'logo_path': None, 'name': 'Domain Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-01', 'revenue': 81100000, 'runtime': 138, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'The world is a stage.', 'title': 'Joker: Folie à Deux', 'video': False, 'vote_average': 5.8, 'vote_count': 435}
# {'adult': False, 'backdrop_path': '/Asg2UUwipAdE87MxtJy7SQo08XI.jpg', 'belongs_to_collection': None, 'budget': 50000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://thecrow.movie/', 'id': 957452, 'imdb_id': 'tt1340094', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Crow', 'overview': 'Soulmates Eric and Shelly are brutally murdered when the demons of her dark past catch up with them. Given the chance to save his true love by sacrificing himself, Eric sets out to seek merciless revenge on their killers, traversing the worlds of the living and the dead to put the wrong things right.', 'popularity': 1690.146, 'poster_path': '/58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg', 'production_companies': [{'id': 342, 'logo_path': '/kZ99mxyNvNgyAFjm7rcl9vfYmU8.png', 'name': 'Davis Films', 'origin_country': 'FR'}, {'id': 6455, 'logo_path': '/mc3rMk0tW5ajjbfqkB8xlp85Cdy.png', 'name': 'Pressman Film', 'origin_country': 'US'}, {'id': 51526, 'logo_path': None, 'name': 'Hassell Free Production', 'origin_country': 'US'}, {'id': 67260, 'logo_path': '/oV2FZfhRcEc1HReC66e1L4t2qPV.png', 'name': 'The Electric Shadow Company', 'origin_country': 'GB'}, {'id': 104363, 'logo_path': '/tKIimrvYUH02D4km00lCEDUYvIF.png', 'name': '30WEST', 'origin_country': 'US'}, {'id': 189103, 'logo_path': '/hu0qcD4k7kfWpdAewqmJSUyZPa7.png', 'name': 'Ashland Hill Media Finance', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-21', 'revenue': 13690814, 'runtime': 111, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'True love never dies.', 'title': 'The Crow', 'video': False, 'vote_average': 5.4, 'vote_count': 484}
# {'adult': False, 'backdrop_path': '/hPIWQT70wQK6akqfLXByEvr62u0.jpg', 'belongs_to_collection': None, 'budget': 14750000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': '', 'id': 726139, 'imdb_id': 'tt25808194', 'origin_country': ['KR'], 'original_language': 'ko', 'original_title': '탈출: 프로젝트 사일런스', 'overview': 'Due to sudden deteriorating weather conditions, visibility on the Airport Bridge is severely impaired, leaving people stranded and at risk of the bridge collapsing due to a series of chain collisions and explosions. Amidst the chaos, the canine subjects "Echo" from the military experiment "Project Silence," who were being transported in secret, break free, and all human survivors become targets of relentless attacks.', 'popularity': 1331.711, 'poster_path': '/fttoFfKikQMwIoV3UVvlCvBhbUw.jpg', 'production_companies': [{'id': 147142, 'logo_path': '/2PLXkCFStjT8Quq3DeDj9dVbM5j.png', 'name': 'Blaad Studios', 'origin_country': 'KR'}, {'id': 128404, 'logo_path': '/dP3usmr6di1jMPH738rvbxdkmSQ.png', 'name': 'CJ ENM', 'origin_country': 'KR'}, {'id': 199265, 'logo_path': '/mv2yDqAgT1ea1eTXZMDr89zX95M.png', 'name': 'CJ ENM Studios', 'origin_country': 'KR'}, {'id': 7036, 'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png', 'name': 'CJ Entertainment', 'origin_country': 'KR'}], 'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}], 'release_date': '2024-07-11', 'revenue': 0, 'runtime': 96, 'spoken_languages': [{'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}], 'status': 'Released', 'tagline': 'Every survivor is a target.', 'title': 'Project Silence', 'video': False, 'vote_average': 7.074, 'vote_count': 102}
# {'adult': False, 'backdrop_path': '/4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg', 'belongs_to_collection': None, 'budget': 78000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10751, 'name': 'Family'}], 'homepage': 'https://www.thewildrobotmovie.com', 'id': 1184918, 'imdb_id': 'tt29623480', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Wild Robot', 'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.", 'popularity': 1328.503, 'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg', 'production_companies': [{'id': 521, 'logo_path': '/3BPX5VGBov8SDqTV7wC1L1xShAS.png', 'name': 'DreamWorks Animation', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-12', 'revenue': 53989150, 'runtime': 102, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'The Wild Robot', 'video': False, 'vote_average': 8.0, 'vote_count': 111}
# {'adult': False, 'backdrop_path': '/gHpTqPqSIC0jZ4J4QyXlVJ0yBcW.jpg', 'belongs_to_collection': {'id': 1215164, 'name': "Kill 'em All Collection", 'poster_path': '/yRE3VydTrAqOY74vHPdNFKS08yV.jpg', 'backdrop_path': '/8hXmI5cWKHedOqNEP2oFIyYa54I.jpg'}, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}], 'homepage': '', 'id': 1215162, 'imdb_id': 'tt6549510', 'origin_country': ['US'], 'original_language': 'en', 'original_title': "Kill 'em All 2", 'overview': "Phillip and Suzanne are retired from the spy game, living peacefully off the grid. That's until their whereabouts are discovered by Vlad, the vengeful brother of their target from the first film.", 'popularity': 1369.344, 'poster_path': '/hgA5hN3NjNNSTXYOmAI6KNKOzbp.jpg', 'production_companies': [{'id': 184844, 'logo_path': '/gsd7K46hkePQejS6hN6Lc5RqBH1.png', 'name': 'Iervolino & Lady Bacardi Entertainment', 'origin_country': 'IT'}, {'id': 23283, 'logo_path': '/AcLUyHmOpEFvYkCJKLiLoLI6NFr.png', 'name': 'Rodin Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-24', 'revenue': 0, 'runtime': 85, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Ido', 'iso_639_1': 'io', 'name': ''}], 'status': 'Released', 'tagline': '', 'title': "Kill 'em All 2", 'video': False, 'vote_average': 6.97, 'vote_count': 67}
# {'adult': False, 'backdrop_path': '/A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg', 'belongs_to_collection': {'id': 945475, 'name': 'Beetlejuice Collection', 'poster_path': '/iTLEUBTDA9U6PR3cpAVCIG3iIXJ.jpg', 'backdrop_path': '/bJ76WnTj7G8dYQSZJvZejna262D.jpg'}, 'budget': 100000000, 'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}], 'homepage': 'https://www.beetlejuicemovie.com', 'id': 917496, 'imdb_id': 'tt2049403', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Beetlejuice Beetlejuice', 'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Betelgeuse, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.", 'popularity': 1105.772, 'poster_path': '/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 360, 'logo_path': '/hbDlIbBdBe0nVFTeZ7hDX3d5n2N.png', 'name': 'Geffen Pictures', 'origin_country': 'US'}, {'id': 81, 'logo_path': '/8wOfUhA7vwU2gbPjQy7Vv3EiF0o.png', 'name': 'Plan B Entertainment', 'origin_country': 'US'}, {'id': 8601, 'logo_path': '/kqubCH3sfBAk4znUj7hjqv8ffgi.png', 'name': 'Tim Burton Productions', 'origin_country': 'US'}, {'id': 216687, 'logo_path': None, 'name': 'Domain Entertainment', 'origin_country': 'US'}, {'id': 228708, 'logo_path': None, 'name': 'Tommy Harper Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-04', 'revenue': 374115014, 'runtime': 105, 'spoken_languages': [{'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}], 'status': 'Released', 'tagline': 'The ghost with the most is back.', 'title': 'Beetlejuice Beetlejuice', 'video': False, 'vote_average': 7.1, 'vote_count': 808}
# {'adult': False, 'backdrop_path': '/zAqBIeO71BFL7bAtP5TFzVjVamy.jpg', 'belongs_to_collection': None, 'budget': 25000000, 'genres': [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}], 'homepage': 'https://www.itendswithus.movie', 'id': 1079091, 'imdb_id': 'tt10655524', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'It Ends with Us', 'overview': "When a woman's first love suddenly reenters her life, her relationship with a charming, but abusive neurosurgeon is upended, and she realizes she must learn to rely on her own strength to make an impossible choice for her future.", 'popularity': 1085.011, 'poster_path': '/cSMdFWmajaX4oUMLx7HEDI84GkP.jpg', 'production_companies': [{'id': 144610, 'logo_path': '/879WnwsOH1oP6NlLY7ChD6vL6lh.png', 'name': 'Wayfarer Studios', 'origin_country': 'US'}, {'id': 194285, 'logo_path': None, 'name': 'Saks Picture Company', 'origin_country': 'US'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-07', 'revenue': 334836337, 'runtime': 131, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'We break the pattern or the pattern breaks us', 'title': 'It Ends with Us', 'video': False, 'vote_average': 7.019, 'vote_count': 687}
# {'adult': False, 'backdrop_path': '/gZWl93sf8AxavYpVT1Un6EF3oCj.jpg', 'belongs_to_collection': {'id': 987044, 'name': 'Joker Collection', 'poster_path': '/jmopX21dlCinxmzd8KLOBFeN2P9.jpg', 'backdrop_path': '/k1YC7mFLvxX4bbD7P8lkcML0Jek.jpg'}, 'budget': 55000000, 'genres': [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}], 'homepage': 'http://www.jokermovie.net/', 'id': 475557, 'imdb_id': 'tt7286456', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Joker', 'overview': 'During the 1980s, a failed stand-up comedian is driven insane and turns to a life of crime and chaos in Gotham City while becoming an infamous psychopathic crime figure.', 'popularity': 974.076, 'poster_path': '/udDclJoHjfjb8Ekgsd4FDteOkCU.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 83036, 'logo_path': None, 'name': 'Joint Effort', 'origin_country': 'US'}, {'id': 79, 'logo_path': '/at4uYdwAAgNRKhZuuFX8ShKSybw.png', 'name': 'Village Roadshow Pictures', 'origin_country': 'US'}, {'id': 13240, 'logo_path': '/aTc07YaNHo8WNgkQSnvLmG6w4nW.png', 'name': 'Bron Studios', 'origin_country': 'CA'}, {'id': 128064, 'logo_path': '/13F3Jf7EFAcREU0xzZqJnVnyGXu.png', 'name': 'DC Films', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2019-10-01', 'revenue': 1078958629, 'runtime': 122, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Put on a happy face.', 'title': 'Joker', 'video': False, 'vote_average': 8.154, 'vote_count': 25319}
# {'adult': False, 'backdrop_path': '/1pbV8uC6EUYOYnPqWfrQFPdAj1O.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}], 'homepage': '', 'id': 1147710, 'imdb_id': 'tt31624258', 'origin_country': ['KR'], 'original_language': 'ko', 'original_title': '하이재킹', 'overview': 'Pilots Tae-in and Gyu-sik are set to fly to Gimpo. Under the guidance of flight attendant Ok-soon, passengers are busy boarding. However, shortly after takeoff, a homemade bomb explodes, turning the cabin into chaos.', 'popularity': 968.532, 'poster_path': '/68jNkFi61MQjrJEqj2up5wZ4w5R.jpg', 'production_companies': [{'id': 112425, 'logo_path': '/2y7W6sMH5AtKjKnPDWJzKv1J4Xx.png', 'name': 'Perfect Storm Film', 'origin_country': 'KR'}, {'id': 235330, 'logo_path': None, 'name': 'Channel Plus', 'origin_country': 'KR'}], 'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}], 'release_date': '2024-06-21', 'revenue': 12971962, 'runtime': 100, 'spoken_languages': [{'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}], 'status': 'Released', 'tagline': 'One passenger with a different destination', 'title': 'Hijack 1971', 'video': False, 'vote_average': 5.878, 'vote_count': 49}
# {'adult': False, 'backdrop_path': '/blqiNjJefmY10Wx6y2vgJJWljJj.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}], 'homepage': '', 'id': 949484, 'imdb_id': 'tt12972134', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Hounds of War', 'overview': 'After a mission goes wrong, only one of a group of mercenaries is left alive to avenge his fallen brothers.', 'popularity': 734.631, 'poster_path': '/lRBT73EWsiQPuqK3YS3BnBW0Zwi.jpg', 'production_companies': [{'id': 56341, 'logo_path': None, 'name': 'Juggernaut Productions', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-29', 'revenue': 0, 'runtime': 94, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Here comes revenge.', 'title': 'Hounds of War', 'video': False, 'vote_average': 6.453, 'vote_count': 74}
# {'adult': False, 'backdrop_path': '/tAwfoDyKiYa4KQdUp3DTMrEs4En.jpg', 'belongs_to_collection': None, 'budget': 75000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://www.transformersmovie.com', 'id': 698687, 'imdb_id': 'tt8864596', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Transformers One', 'overview': 'The untold origin story of Optimus Prime and Megatron, better known as sworn enemies, but once were friends bonded like brothers who changed the fate of Cybertron forever.', 'popularity': 704.262, 'poster_path': '/qbkAqmmEIZfrCO8ZQAuIuVMlWoV.jpg', 'production_companies': [{'id': 24955, 'logo_path': '/pUZAeCMZlLBBUItAl11Ip2XikdD.png', 'name': 'Paramount Animation', 'origin_country': 'US'}, {'id': 435, 'logo_path': '/AjzK0s2w1GtLfR4hqCjVSYi0Sr8.png', 'name': 'di Bonaventura Pictures', 'origin_country': 'US'}, {'id': 38831, 'logo_path': None, 'name': 'DeSanto/Murphy Productions', 'origin_country': 'US'}, {'id': 6734, 'logo_path': '/u55FhlG6vFNzSVKLcmnFFwLb2cc.png', 'name': 'Bay Films', 'origin_country': 'US'}, {'id': 114732, 'logo_path': '/tNCbisMxO5mX2X2bOQxHHQZVYnT.png', 'name': 'New Republic Pictures', 'origin_country': 'US'}, {'id': 207846, 'logo_path': '/1Qep9fdnqCjWFKYpwNvwy2zoRNQ.png', 'name': 'Hasbro Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-11', 'revenue': 71822359, 'runtime': 104, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Witness the origin.', 'title': 'Transformers One', 'video': False, 'vote_average': 7.374, 'vote_count': 119}
# {'adult': False, 'backdrop_path': '/mKOBdgaEFguADkJhfFslY7TYxIh.jpg', 'belongs_to_collection': None, 'budget': 115000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://borderlands.movie', 'id': 365177, 'imdb_id': 'tt4978420', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Borderlands', 'overview': 'Returning to her home planet, an infamous bounty hunter forms an unexpected alliance with a team of unlikely heroes. Together, they battle monsters and dangerous bandits to protect a young girl who holds the key to unimaginable power.', 'popularity': 723.922, 'poster_path': '/865DntZzOdX6rLMd405R0nFkLmL.jpg', 'production_companies': [{'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png', 'name': 'Lionsgate', 'origin_country': 'US'}, {'id': 14439, 'logo_path': None, 'name': 'Arad Productions', 'origin_country': 'US'}, {'id': 123244, 'logo_path': '/7eH1Y4RIuontJJXVmmSRrNUMZhU.png', 'name': 'Picturestart', 'origin_country': 'US'}, {'id': 158612, 'logo_path': '/uuByByK2kn72I2c6MGsoa5YQlcJ.png', 'name': 'Gearbox Studios', 'origin_country': 'US'}, {'id': 181160, 'logo_path': '/bfngnSWlPGca8MZG2veYx4JYgOz.png', 'name': '2K', 'origin_country': 'US'}, {'id': 147591, 'logo_path': '/uMVoIH3rug7F3BsU1FGVJos4yrR.png', 'name': 'Hercules Film Fund', 'origin_country': 'LU'}], 'production_countries': [{'iso_3166_1': 'LU', 'name': 'Luxembourg'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-07', 'revenue': 30863794, 'runtime': 101, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Chaos loves company.', 'title': 'Borderlands', 'video': False, 'vote_average': 5.884, 'vote_count': 645}
# {'adult': False, 'backdrop_path': '/vt37v6ouquokPYeEg3xqkzKjHRj.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 53, 'name': 'Thriller'}], 'homepage': '', 'id': 1248753, 'imdb_id': 'tt31450182', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Amber Alert', 'overview': 'An ordinary rideshare becomes a high-stakes game of cat and mouse when Jaq and Shane receive an alert of a child abduction on their phones. Quickly realizing they are behind a car that matches the description of the kidnapper’s, Jaq and Shane desperately race against time to save the child’s life.', 'popularity': 470.763, 'poster_path': '/6pP9HlVFDLqChRiWhN1E7HdJF4I.jpg', 'production_companies': [{'id': 147008, 'logo_path': '/yfE034nTSk0IqPNZCYMAJfSzWqb.png', 'name': 'Hungry Bull Productions', 'origin_country': 'US'}, {'id': 20312, 'logo_path': '/iYmytRQt5jqlBIEaMQ0Cb6iAHh8.png', 'name': 'TPC', 'origin_country': 'US'}, {'id': 157721, 'logo_path': None, 'name': 'Bluefields Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-27', 'revenue': 0, 'runtime': 91, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Two strangers are her only hope.', 'title': 'Amber Alert', 'video': False, 'vote_average': 5.6, 'vote_count': 47}
# {'adult': False, 'backdrop_path': '/9SSEUrSqhljBMzRe4aBTh17rUaC.jpg', 'belongs_to_collection': None, 'budget': 80000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://www.20thcenturystudios.com/movies/alien-romulus', 'id': 945961, 'imdb_id': 'tt18412256', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Alien: Romulus', 'overview': 'While scavenging the deep ends of a derelict space station, a group of young space colonizers come face to face with the most terrifying life form in the universe.', 'popularity': 565.572, 'poster_path': '/b33nnKl1GSFbao4l3fZDDqsMx0F.jpg', 'production_companies': [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png', 'name': '20th Century Studios', 'origin_country': 'US'}, {'id': 221347, 'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png', 'name': 'Scott Free Productions', 'origin_country': 'US'}, {'id': 401, 'logo_path': '/t7mM3DvQ9MwDT3YzMCBrkWpWiiz.png', 'name': 'Brandywine Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-13', 'revenue': 341521150, 'runtime': 119, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Everyone will hear you scream.', 'title': 'Alien: Romulus', 'video': False, 'vote_average': 7.1, 'vote_count': 1122}
# {'adult': False, 'backdrop_path': '/wSZbtiFIK1fkKZdSRtn2kz2Ttfd.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://www.netflix.com/title/81702144', 'id': 1139817, 'imdb_id': 'tt28494829', 'origin_country': ['KR'], 'original_language': 'ko', 'original_title': '무도실무관', 'overview': "A talented martial artist who can't walk past a person in need unites with a probation officer to fight and prevent crime as a martial arts officer.", 'popularity': 546.842, 'poster_path': '/rEaJSXAlNfdhRpDHiNcJsoUa9qE.jpg', 'production_companies': [{'id': 127541, 'logo_path': '/Aq35mXuZv7lhPm8a60YKRaB9Vek.png', 'name': 'Climax Studios', 'origin_country': 'KR'}, {'id': 194623, 'logo_path': '/siDtLju4jDOAeHQgvnJgsr4T9Bl.png', 'name': 'STUDIO706', 'origin_country': 'KR'}], 'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}], 'release_date': '2024-09-10', 'revenue': 0, 'runtime': 108, 'spoken_languages': [{'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}], 'status': 'Released', 'tagline': 'Strike crime before it strikes the world.', 'title': 'Officer Black Belt', 'video': False, 'vote_average': 7.858, 'vote_count': 169}
# {'adult': False, 'backdrop_path': '/jfC2xCBD8a5QJNd5yY3q23E8i7U.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}], 'homepage': '', 'id': 1186947, 'imdb_id': 'tt32276312', 'origin_country': ['BR'], 'original_language': 'pt', 'original_title': 'Bandida - A Número Um', 'overview': 'At the age of nine, Rebeca is sold by her grandmother to the bookseller who ran Rocinha. Disputed by bicheiros and drug dealers, the community is going through changes in power. Rebeca becomes the wife of the chief drug dealer and, with the death of her partner, his successor. The electrifying trajectory of crime, violence, drugs and love of a female drug kingpin in Rocinha, Rio de Janeiro in the 1980s.', 'popularity': 588.225, 'poster_path': '/rGS8SzheANVQicNba0GCE6w1XHb.jpg', 'production_companies': [{'id': 167711, 'logo_path': '/3pBs0IlFWRddrjLWpT1uV4R7qWS.png', 'name': 'Tx Filmes', 'origin_country': 'BR'}, {'id': 93195, 'logo_path': '/qjk6yikGcCAqMQvi7Jo2juoIMY.png', 'name': 'Paris Entretenimento', 'origin_country': 'BR'}, {'id': 202798, 'logo_path': '/tU2YHFlXX6nFMZlfFJ2yPzkkhdM.png', 'name': 'Claro', 'origin_country': 'BR'}, {'id': 7764, 'logo_path': '/6YQPMXHq7juxomK9Sy3zBqbalsD.png', 'name': 'Telecine', 'origin_country': 'BR'}, {'id': 40994, 'logo_path': '/kyl2LrS9dGnBcJRLx6ST2Qsaxan.png', 'name': 'RioFilme', 'origin_country': 'BR'}], 'production_countries': [{'iso_3166_1': 'BR', 'name': 'Brazil'}], 'release_date': '2024-06-20', 'revenue': 0, 'runtime': 80, 'spoken_languages': [{'english_name': 'Portuguese', 'iso_639_1': 'pt', 'name': 'Português'}], 'status': 'Released', 'tagline': '', 'title': 'Outlaw', 'video': False, 'vote_average': 6.065, 'vote_count': 69}
# {'adult': False, 'backdrop_path': '/ArRR0UvZSV1ONjEm84IGZSWHqYq.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://epic-pictures.com/film/beezel', 'id': 1291594, 'imdb_id': 'tt28999532', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Beezel', 'overview': 'Over six tumultuous decades, three unwitting guests of a cursed New England home stumble upon a sinister secret dwelling beneath its floors - an eternal witch with an insatiable thirst for the souls of the living.', 'popularity': 475.008, 'poster_path': '/a9gZxhG98LATZJGy1vWssyjVkk.jpg', 'production_companies': [{'id': 111927, 'logo_path': None, 'name': 'Social House Films', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-20', 'revenue': 0, 'runtime': 82, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'The blind witch waits.', 'title': 'Beezel', 'video': False, 'vote_average': 6.1, 'vote_count': 14}
# {'adult': False, 'backdrop_path': '/yDHYTfA3R0jFYba16jBB1ef8oIt.jpg', 'belongs_to_collection': {'id': 448150, 'name': 'Deadpool Collection', 'poster_path': '/30c5jO7YEXuF8KiWXLg9m28GWDA.jpg', 'backdrop_path': '/hBQOWY8qWXJVFAc8yLTh1teIu43.jpg'}, 'budget': 200000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': 'https://www.marvel.com/movies/deadpool-and-wolverine', 'id': 533535, 'imdb_id': 'tt6263850', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Deadpool & Wolverine', 'overview': 'A listless Wade Wilson toils away in civilian life with his days as the morally flexible mercenary, Deadpool, behind him. But when his homeworld faces an existential threat, Wade must reluctantly suit-up again with an even more reluctant Wolverine.', 'popularity': 5099.804, 'poster_path': '/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg', 'production_companies': [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 104228, 'logo_path': '/hx0C1XcSxGgat8N62GpxoJGTkCk.png', 'name': 'Maximum Effort', 'origin_country': 'US'}, {'id': 2575, 'logo_path': '/9YJrHYlcfHtwtulkFMAies3aFEl.png', 'name': '21 Laps Entertainment', 'origin_country': 'US'}, {'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png', 'name': '20th Century Studios', 'origin_country': 'US'}, {'id': 176762, 'logo_path': None, 'name': 'Kevin Feige Productions', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-07-24', 'revenue': 1326387384, 'runtime': 128, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Come together.', 'title': 'Deadpool & Wolverine', 'video': False, 'vote_average': 7.741, 'vote_count': 4037}
# {'adult': False, 'backdrop_path': '/lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg', 'belongs_to_collection': {'id': 86066, 'name': 'Despicable Me Collection', 'poster_path': '/95prV91f4DxkBnLU43YjLbU1m3q.jpg', 'backdrop_path': '/37xamYKRUGCRux532lKcZdVGYuR.jpg'}, 'budget': 100000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://www.despicable.me', 'id': 519182, 'imdb_id': 'tt7510222', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Despicable Me 4', 'overview': 'Gru and Lucy and their girls—Margo, Edith and Agnes—welcome a new member to the Gru family, Gru Jr., who is intent on tormenting his dad. Gru also faces a new nemesis in Maxime Le Mal and his femme fatale girlfriend Valentina, forcing the family to go on the run.', 'popularity': 2524.611, 'poster_path': '/wWba3TaojhK7NdycRhoQpsG0FaH.jpg', 'production_companies': [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 6704, 'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png', 'name': 'Illumination', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-06-20', 'revenue': 953140610, 'runtime': 94, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Things just got a little more despicable.', 'title': 'Despicable Me 4', 'video': False, 'vote_average': 7.145, 'vote_count': 1892}
# {'adult': False, 'backdrop_path': '/9R9Za5kybgl5AhuCNoK3gngaBdG.jpg', 'belongs_to_collection': None, 'budget': 15000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://www.speaknoevilmovie.com', 'id': 1114513, 'imdb_id': 'tt27534307', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Speak No Evil', 'overview': 'When an American family is invited to spend the weekend at the idyllic country estate of a charming British family they befriended on vacation, what begins as a dream holiday soon warps into a snarled psychological nightmare.', 'popularity': 2281.291, 'poster_path': '/fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg', 'production_companies': [{'id': 3172, 'logo_path': '/rzKluDcRkIwHZK2pHsiT667A2Kw.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-11', 'revenue': 57652430, 'runtime': 110, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'Speak No Evil', 'video': False, 'vote_average': 7.344, 'vote_count': 506}
# {'adult': False, 'backdrop_path': '/7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg', 'belongs_to_collection': None, 'budget': 17500000, 'genres': [{'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://www.the-match-factory.com/catalogue/films/the-substance.html', 'id': 933260, 'imdb_id': 'tt17526714', 'origin_country': ['GB'], 'original_language': 'en', 'original_title': 'The Substance', 'overview': 'A fading celebrity decides to use a black market drug, a cell-replicating substance that temporarily creates a younger, better version of herself.', 'popularity': 1595.704, 'poster_path': '/lqoMzCcZYEFK729d6qzt349fB4o.jpg', 'production_companies': [{'id': 10163, 'logo_path': '/16KWBMmfPX0aJzDExDrPxSLj0Pg.png', 'name': 'Working Title Films', 'origin_country': 'GB'}, {'id': 233939, 'logo_path': None, 'name': 'Blacksmith', 'origin_country': 'FR'}], 'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-07', 'revenue': 10492678, 'runtime': 141, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'If you follow the instructions, what could go wrong?', 'title': 'The Substance', 'video': False, 'vote_average': 7.3, 'vote_count': 230}
# {'adult': False, 'backdrop_path': '/p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg', 'belongs_to_collection': {'id': 1022790, 'name': 'Inside Out Collection', 'poster_path': '/kvJqs0vm29U0xJa373wlzHb3FRh.jpg', 'backdrop_path': '/7U2m2dMSIfHx2gWXKq78Xj1weuH.jpg'}, 'budget': 200000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}], 'homepage': 'https://movies.disney.com/inside-out-2', 'id': 1022789, 'imdb_id': 'tt22022452', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Inside Out 2', 'overview': "Teenager Riley's mind headquarters is undergoing a sudden demolition to make room for something entirely unexpected: new Emotions! Joy, Sadness, Anger, Fear and Disgust, who’ve long been running a successful operation by all accounts, aren’t sure how to feel when Anxiety shows up. And it looks like she’s not alone.", 'popularity': 1561.87, 'poster_path': '/vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg', 'production_companies': [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png', 'name': 'Pixar', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-06-11', 'revenue': 1682636477, 'runtime': 97, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Make room for new emotions.', 'title': 'Inside Out 2', 'video': False, 'vote_average': 7.64, 'vote_count': 4161}
# {'adult': False, 'backdrop_path': '/uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg', 'belongs_to_collection': {'id': 1326786, 'name': 'Wolfs Collection', 'poster_path': '/i07rSqX1ovPUxsDIfSdares5Iia.jpg', 'backdrop_path': '/1kfIIYMhnCC6JTq9M4Zxz62YXfs.jpg'}, 'budget': 0, 'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'name': 'Thriller'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://tv.apple.com/movie/umc.cmc.c3xhu25rw4jxxxzq4oio6snu', 'id': 877817, 'imdb_id': 'tt14257582', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Wolfs', 'overview': "Hired to cover up a high-profile crime, a fixer soon finds his night spiralling out of control when he's forced to work with an unexpected counterpart.", 'popularity': 1693.793, 'poster_path': '/vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg', 'production_companies': [{'id': 1782, 'logo_path': '/d1mlUfuG0NoQ4x0C7bK80wLGWA1.png', 'name': 'Smoke House Pictures', 'origin_country': 'US'}, {'id': 81, 'logo_path': '/8wOfUhA7vwU2gbPjQy7Vv3EiF0o.png', 'name': 'Plan B Entertainment', 'origin_country': 'US'}, {'id': 194232, 'logo_path': '/oE7H93u8sy5vvW5EH3fpCp68vvB.png', 'name': 'Apple Studios', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-20', 'revenue': 0, 'runtime': 108, 'spoken_languages': [{'english_name': 'Croatian', 'iso_639_1': 'hr', 'name': 'Hrvatski'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': "They're not partners. They're not friends. They're wolfs.", 'title': 'Wolfs', 'video': False, 'vote_average': 6.591, 'vote_count': 378}
# {'adult': False, 'backdrop_path': '/1H0l07FGCx3e9G0zLBGiIfHk9Zc.jpg', 'belongs_to_collection': {'id': 987044, 'name': 'Joker Collection', 'poster_path': '/jmopX21dlCinxmzd8KLOBFeN2P9.jpg', 'backdrop_path': '/k1YC7mFLvxX4bbD7P8lkcML0Jek.jpg'}, 'budget': 195000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://www.joker.movie', 'id': 889737, 'imdb_id': 'tt11315808', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Joker: Folie à Deux', 'overview': "While struggling with his dual identity, Arthur Fleck not only stumbles upon true love, but also finds the music that's always been inside him.", 'popularity': 1372.519, 'poster_path': '/if8QiqCI7WAGImKcJCfzp6VTyKA.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 83036, 'logo_path': None, 'name': 'Joint Effort', 'origin_country': 'US'}, {'id': 216687, 'logo_path': None, 'name': 'Domain Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-01', 'revenue': 81100000, 'runtime': 138, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'The world is a stage.', 'title': 'Joker: Folie à Deux', 'video': False, 'vote_average': 5.8, 'vote_count': 435}
# {'adult': False, 'backdrop_path': '/Asg2UUwipAdE87MxtJy7SQo08XI.jpg', 'belongs_to_collection': None, 'budget': 50000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://thecrow.movie/', 'id': 957452, 'imdb_id': 'tt1340094', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Crow', 'overview': 'Soulmates Eric and Shelly are brutally murdered when the demons of her dark past catch up with them. Given the chance to save his true love by sacrificing himself, Eric sets out to seek merciless revenge on their killers, traversing the worlds of the living and the dead to put the wrong things right.', 'popularity': 1690.146, 'poster_path': '/58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg', 'production_companies': [{'id': 342, 'logo_path': '/kZ99mxyNvNgyAFjm7rcl9vfYmU8.png', 'name': 'Davis Films', 'origin_country': 'FR'}, {'id': 6455, 'logo_path': '/mc3rMk0tW5ajjbfqkB8xlp85Cdy.png', 'name': 'Pressman Film', 'origin_country': 'US'}, {'id': 51526, 'logo_path': None, 'name': 'Hassell Free Production', 'origin_country': 'US'}, {'id': 67260, 'logo_path': '/oV2FZfhRcEc1HReC66e1L4t2qPV.png', 'name': 'The Electric Shadow Company', 'origin_country': 'GB'}, {'id': 104363, 'logo_path': '/tKIimrvYUH02D4km00lCEDUYvIF.png', 'name': '30WEST', 'origin_country': 'US'}, {'id': 189103, 'logo_path': '/hu0qcD4k7kfWpdAewqmJSUyZPa7.png', 'name': 'Ashland Hill Media Finance', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-21', 'revenue': 13690814, 'runtime': 111, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'True love never dies.', 'title': 'The Crow', 'video': False, 'vote_average': 5.4, 'vote_count': 484}
# {'adult': False, 'backdrop_path': '/hPIWQT70wQK6akqfLXByEvr62u0.jpg', 'belongs_to_collection': None, 'budget': 14750000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': '', 'id': 726139, 'imdb_id': 'tt25808194', 'origin_country': ['KR'], 'original_language': 'ko', 'original_title': '탈출: 프로젝트 사일런스', 'overview': 'Due to sudden deteriorating weather conditions, visibility on the Airport Bridge is severely impaired, leaving people stranded and at risk of the bridge collapsing due to a series of chain collisions and explosions. Amidst the chaos, the canine subjects "Echo" from the military experiment "Project Silence," who were being transported in secret, break free, and all human survivors become targets of relentless attacks.', 'popularity': 1331.711, 'poster_path': '/fttoFfKikQMwIoV3UVvlCvBhbUw.jpg', 'production_companies': [{'id': 147142, 'logo_path': '/2PLXkCFStjT8Quq3DeDj9dVbM5j.png', 'name': 'Blaad Studios', 'origin_country': 'KR'}, {'id': 128404, 'logo_path': '/dP3usmr6di1jMPH738rvbxdkmSQ.png', 'name': 'CJ ENM', 'origin_country': 'KR'}, {'id': 199265, 'logo_path': '/mv2yDqAgT1ea1eTXZMDr89zX95M.png', 'name': 'CJ ENM Studios', 'origin_country': 'KR'}, {'id': 7036, 'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png', 'name': 'CJ Entertainment', 'origin_country': 'KR'}], 'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}], 'release_date': '2024-07-11', 'revenue': 0, 'runtime': 96, 'spoken_languages': [{'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}], 'status': 'Released', 'tagline': 'Every survivor is a target.', 'title': 'Project Silence', 'video': False, 'vote_average': 7.074, 'vote_count': 102}
# {'adult': False, 'backdrop_path': '/4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg', 'belongs_to_collection': None, 'budget': 78000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10751, 'name': 'Family'}], 'homepage': 'https://www.thewildrobotmovie.com', 'id': 1184918, 'imdb_id': 'tt29623480', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Wild Robot', 'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.", 'popularity': 1328.503, 'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg', 'production_companies': [{'id': 521, 'logo_path': '/3BPX5VGBov8SDqTV7wC1L1xShAS.png', 'name': 'DreamWorks Animation', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-12', 'revenue': 53989150, 'runtime': 102, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'The Wild Robot', 'video': False, 'vote_average': 8.0, 'vote_count': 111}
# ...
# {'adult': False, 'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg', 'belongs_to_collection': {'id': 558216, 'name': 'Venom Collection', 'poster_path': '/hoTLlTIohrzQ13HQVkZrDlvffuT.jpg', 'backdrop_path': '/vq340s8DxA5Q209FT8PHA6CXYOx.jpg'}, 'budget': 110000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 12, 'name': 'Adventure'}], 'homepage': 'https://venom.movie', 'id': 912649, 'imdb_id': 'tt16366836', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Venom: The Last Dance', 'overview': "Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.", 'popularity': 317.03, 'poster_path': '/aosm8NMQ3UyoBVpSxyimorCQykC.jpg', 'production_companies': [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 53462, 'logo_path': '/nx8B3Phlcse02w86RW4CJqzCnfL.png', 'name': 'Matt Tolmach Productions', 'origin_country': 'US'}, {'id': 91797, 'logo_path': None, 'name': 'Hutch Parker Entertainment', 'origin_country': 'US'}, {'id': 14439, 'logo_path': None, 'name': 'Arad Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-23', 'revenue': 0, 'runtime': 0, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Post Production', 'tagline': "'Til death do they part.", 'title': 'Venom: The Last Dance', 'video': False, 'vote_average': 0.0, 'vote_count': 0}
# {'adult': False, 'backdrop_path': '/h9YlRHAZWOWtGonllmj6JJg1FrE.jpg', 'belongs_to_collection': None, 'budget': 25600000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}], 'homepage': 'http://www.dragonkeepermovie.com', 'id': 588648, 'imdb_id': 'tt7093904', 'origin_country': ['CN', 'ES'], 'original_language': 'zh', 'original_title': 'Dragonkeeper', 'overview': 'Set in Han Imperial China, the plot follows the adventures of enslaved girl Ping with ancient dragon Long Danzi. Dragons had been banished from the kingdom. Ping, an orphan, finds one of the last remaining dragon eggs. Palace guards force Ping to run away in order to return the dragon egg to the ocean and save all dragons from extinction. Ping discovers that she is a true Dragonkeeper.', 'popularity': 316.685, 'poster_path': '/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg', 'production_companies': [{'id': 67412, 'logo_path': '/vgVqq5hunVs8GN5Je9d9rG7Q2NU.png', 'name': 'Movistar+', 'origin_country': 'ES'}, {'id': 29566, 'logo_path': '/wHbtRtUnXGNzX0riQIpq1fcgueq.png', 'name': 'Atresmedia', 'origin_country': 'ES'}, {'id': 115983, 'logo_path': None, 'name': 'China Film Animation', 'origin_country': 'CN'}, {'id': 222691, 'logo_path': None, 'name': 'Guardián de Dragones AIE', 'origin_country': ''}, {'id': 202198, 'logo_path': None, 'name': 'Telefonica', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_3166_1': 'ES', 'name': 'Spain'}], 'release_date': '2024-04-11', 'revenue': 5427272, 'runtime': 99, 'spoken_languages': [{'english_name': 'Mandarin', 'iso_639_1': 'zh', 'name': '普通话'}, {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Everybody just saw a girl.', 'title': 'Dragonkeeper', 'video': False, 'vote_average': 7.275, 'vote_count': 111}
# {'adult': False, 'backdrop_path': '/p5kpFS0P3lIwzwzHBOULQovNWyj.jpg', 'belongs_to_collection': None, 'budget': 30000000, 'genres': [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}, {'id': 27, 'name': 'Horror'}], 'homepage': 'https://www.trapthefilm.com', 'id': 1032823, 'imdb_id': 'tt26753003', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Trap', 'overview': "A father and teen daughter attend a pop concert, where they realize they're at the center of a dark and sinister event.", 'popularity': 311.433, 'poster_path': '/jwoaKYVqPgYemFpaANL941EF94R.jpg', 'production_companies': [{'id': 12236, 'logo_path': '/bVu0qQm4GujSTCvZZz9S3rHDczA.png', 'name': 'Blinding Edge Pictures', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-07-31', 'revenue': 82406909, 'runtime': 105, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '30,000 fans. 300 cops. 1 serial killer. No escape.', 'title': 'Trap', 'video': False, 'vote_average': 6.522, 'vote_count': 1265}
# {'adult': False, 'backdrop_path': '/iURqo6oIwbeegIwWXx5qrBsDcPk.jpg', 'belongs_to_collection': None, 'budget': 40000000, 'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://www.haroldandthepurplecrayon.movie', 'id': 826510, 'imdb_id': 'tt1609486', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Harold and the Purple Crayon', 'overview': "Inside of his book, adventurous Harold can make anything come to life simply by drawing it. After he grows up and draws himself off the book's pages and into the physical world, Harold finds he has a lot to learn about real life.", 'popularity': 303.501, 'poster_path': '/qtW6bWUEqfPLaD6KnetIlSG4adf.jpg', 'production_companies': [{'id': 1302, 'logo_path': '/zC3b70ixHh89qJIikLQPEvLqbPM.png', 'name': 'Davis Entertainment', 'origin_country': 'US'}, {'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-07-31', 'revenue': 24982787, 'runtime': 90, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Everything he draws is about to get real.', 'title': 'Harold and the Purple Crayon', 'video': False, 'vote_average': 7.1, 'vote_count': 147}
# {'adult': False, 'backdrop_path': '/tCQfubckzzcuCbsGugkpLhfjS5z.jpg', 'belongs_to_collection': None, 'budget': 30000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://www.peacocktv.com/stream-movies/the-killer', 'id': 970347, 'imdb_id': 'tt1121948', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Killer', 'overview': 'Zee is a feared contract killer known as "the Queen of the Dead," but when she refuses to murder a young blind woman, she finds herself hunted both by criminal colleagues and a determined police detective.', 'popularity': 302.421, 'poster_path': '/6PCnxKZZIVRanWb710pNpYVkCSw.jpg', 'production_companies': [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 507, 'logo_path': '/aRmHe6GWxYMRCQljF75rn2B9Gv8.png', 'name': 'Atlas Entertainment', 'origin_country': 'US'}, {'id': 172860, 'logo_path': None, 'name': 'A Better Tomorrow Films', 'origin_country': 'US'}, {'id': 8147, 'logo_path': '/q6HOAdSNgCbeOqwoMVRc6REgbXF.png', 'name': 'Entertainment One', 'origin_country': 'CA'}], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-22', 'revenue': 0, 'runtime': 126, 'spoken_languages': [{'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Some alliances form. Others will crumble.', 'title': 'The Killer', 'video': False, 'vote_average': 6.597, 'vote_count': 252}
# {'adult': False, 'backdrop_path': '/jf1V00dZdNkVfEq7VPk8frrlELk.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}], 'homepage': 'https://www.max.com/movies/salems-lot/b1aaea47-b2e8-4418-a181-91de7102d04f', 'id': 748230, 'imdb_id': 'tt10245072', 'origin_country': ['US'], 'original_language': 'en', 'original_title': "Salem's Lot", 'overview': "Author Ben Mears returns to his childhood home of Jerusalem's Lot only to discover his hometown is being preyed upon by a bloodthirsty vampire.", 'popularity': 283.882, 'poster_path': '/j7ncdqBVufydVzVtxmXu8Ago4ox.jpg', 'production_companies': [{'id': 12, 'logo_path': '/2ycs64eqV5rqKYHyQK0GVoKGvfX.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQhQZY82lgnCUO.png', 'name': 'Atomic Monster', 'origin_country': 'US'}, {'id': 829, 'logo_path': '/aXqwCvJSCDbTclkxAYfsT1l4Dsa.png', 'name': 'Vertigo Entertainment', 'origin_country': 'US'}, {'id': 2428, 'logo_path': None, 'name': 'Wolper Organization', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-03', 'revenue': 0, 'runtime': 113, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Be careful what you invite inside.', 'title': "Salem's Lot", 'video': False, 'vote_average': 6.362, 'vote_count': 134}
# {'adult': False, 'backdrop_path': '/oBmwaZ3NVa3JyZnv1qCo0znxjUw.jpg', 'belongs_to_collection': None, 'budget': 4000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://www.strangedarlingfilm.com', 'id': 1029281, 'imdb_id': 'tt22375054', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Strange Darling', 'overview': 'Nothing is what it seems when a twisted one-night stand spirals into a serial killer’s vicious murder spree.', 'popularity': 271.705, 'poster_path': '/rhhE4U49hM50s7XCYZ8dHShhM7x.jpg', 'production_companies': [{'id': 14, 'logo_path': '/m6AHu84oZQxvq7n1rsvMNJIAsMu.png', 'name': 'Miramax', 'origin_country': 'US'}, {'id': 169906, 'logo_path': '/vEiG2JXNpnJD8k8jkF6cHOpsFLe.png', 'name': 'Spooky Pictures', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-22', 'revenue': 3504687, 'runtime': 97, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Love hurts.', 'title': 'Strange Darling', 'video': False, 'vote_average': 7.011, 'vote_count': 88}
# {'adult': False, 'backdrop_path': '/AjTodtZJlQxycfRPktnUTpknblv.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}], 'homepage': 'https://gracieandpedro.com/', 'id': 1207830, 'imdb_id': 'tt29258548', 'origin_country': ['CA'], 'original_language': 'en', 'original_title': 'Gracie & Pedro: Pets to the Rescue', 'overview': 'Family frenemies, Gracie and Pedro, must put their differences aside, embarking on a thrilling quest packed with perilous escapades in order to reunite with their owners.', 'popularity': 262.058, 'poster_path': '/1agSI7NGvagr720za8XAubtqUoB.jpg', 'production_companies': [{'id': 213963, 'logo_path': None, 'name': 'Second Chance Productions', 'origin_country': ''}, {'id': 142108, 'logo_path': None, 'name': 'Luminescence', 'origin_country': 'HU'}, {'id': 133835, 'logo_path': None, 'name': 'GTE Productions', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'ZA', 'name': 'South Africa'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-05-01', 'revenue': 664443, 'runtime': 89, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Unite like cats and dogs.', 'title': 'Gracie & Pedro: Pets to the Rescue', 'video': False, 'vote_average': 7.273, 'vote_count': 11}
# {'adult': False, 'backdrop_path': '/t3LicFpYHeYpwqm7L5wDpd22hL5.jpg', 'belongs_to_collection': {'id': 1241, 'name': 'Harry Potter Collection', 'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg', 'backdrop_path': '/xN6SBJVG8jqqKQrgxthn3J2m49S.jpg'}, 'budget': 125000000, 'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}], 'homepage': 'https://www.warnerbros.com/movies/harry-potter-and-sorcerers-stone/', 'id': 671, 'imdb_id': 'tt0241527', 'origin_country': ['GB'], 'original_language': 'en', 'original_title': "Harry Potter and the Philosopher's Stone", 'overview': "Harry Potter has lived under the stairs at his aunt and uncle's house his whole life. But on his 11th birthday, he learns he's a powerful wizard—with a place waiting for him at the Hogwarts School of Witchcraft and Wizardry. As he learns to harness his newfound powers with the help of the school's kindly headmaster, Harry uncovers the truth about his parents' deaths—and about the villain who's to blame.", 'popularity': 246.557, 'poster_path': '/wuMc08IPKEatf9rnMNXvIDxqP4W.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 437, 'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png', 'name': 'Heyday Films', 'origin_country': 'GB'}, {'id': 436, 'logo_path': '/A7WCkG3F0NFvjGCwUnclpGdIu9E.png', 'name': '1492 Pictures', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2001-11-16', 'revenue': 976475550, 'runtime': 152, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Let the magic begin.', 'title': "Harry Potter and the Philosopher's Stone", 'video': False, 'vote_average': 7.914, 'vote_count': 27161}
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              80 non-null     bool
#  1   backdrop_path      80 non-null     object
#  2   genre_ids          80 non-null     object
#  3   id                 80 non-null     int64
#  4   original_language  80 non-null     object
#  5   original_title     80 non-null     object
#  6   overview           80 non-null     object
#  7   popularity         80 non-null     float64
#  8   poster_path        80 non-null     object
#  9   release_date       80 non-null     object
#  10  title              80 non-null     object
#  11  video              80 non-null     bool
#  12  vote_average       80 non-null     float64
#  13  vote_count         80 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 8.3+ KB
# None

# %%
fullConDf = pd.merge(ConDf, money, how="inner", on="id")

# %%
sns.regplot(data=fullConDf, x='revenue', y='budget')
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='budget'>

# %%
def get_best_fit(df, x, y):
    
    m = 0
    b = 0
    
    #Calculate Residuals
    res = 0
    for count in range(100):
        m = m + 1
        b = 0
        
        res = 0
        
        for i in range(len(data)):
            pred_y = (m * df.loc[i][x]) + b
            act_y = df.loc[i][y]
            temp = act_y - pred_y
            temp = temp ** 2
            res = res + temp
        print(res)
    
    return(m, b, res)

# %%
get_best_fit(fullConDf, "budget", "revenue")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23416\2464078698.py in <module>
# ----> 1 get_best_fit(fullConDf, "budget", "revenue")
#
# ~\AppData\Local\Temp\ipykernel_23416\2987873317.py in get_best_fit(df, x, y)
#       8         pred_y = (m * df.loc[0][x] + b)
#       9         act_y = df.loc[0][y]
# ---> 10         res = [pred_y - act_y]**2
#      11
#      12     return(m, b, res)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
