# %%
import pandas as pd
import seaborn as sns
import requests
import matplotlib.pyplot as plt

# %%
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

nowPlaying = requests.get(url, headers=headers)
nowPlaying = nowPlaying.json()
now = pd.DataFrame(nowPlaying["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg     [878, 53, 18]  1125510
# 4  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg      [35, 14, 27]   917496
#
#   original_language           original_title  \
# 0                en           The Wild Robot
# 1                en            The Substance
# 2                en                   Azrael
# 3                es                El hoyo 2
# 4                en  Beetlejuice Beetlejuice
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  After a mysterious leader imposes his law in a...    1781.297
# 4  After a family tragedy, three generations of t...    2059.319
#
#                         poster_path release_date                    title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12           The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                   Azrael
# 3  /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27           The Platform 2
# 4  /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
#
#    video  vote_average  vote_count
# 0  False         8.700        1060
# 1  False         7.300         718
# 2  False         6.000          78
# 3  False         5.700         645
# 4  False         7.203        1445

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

popular = requests.get(url, headers=headers)
popular = popular.json()
nowPopular = pd.DataFrame(popular["results"])
nowPopular.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg         [878, 27]   945961
# 3  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg     [28, 35, 878]   533535
# 4  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
#
#   original_language        original_title  \
# 0                en        The Wild Robot
# 1                en         The Substance
# 2                en        Alien: Romulus
# 3                en  Deadpool & Wolverine
# 4                en                Azrael
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  While scavenging the deep ends of a derelict s...    6369.381
# 3  A listless Wade Wilson toils away in civilian ...    2958.871
# 4  In a world where no one speaks, a devout femal...    2309.545
#
#                         poster_path release_date                 title  video  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12        The Wild Robot  False
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07         The Substance  False
# 2  /b33nnKl1GSFbao4l3fZDDqsMx0F.jpg   2024-08-13        Alien: Romulus  False
# 3  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24  Deadpool & Wolverine  False
# 4  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                Azrael  False
#
#    vote_average  vote_count
# 0         8.700        1059
# 1         7.300         718
# 2         7.292        1706
# 3         7.700        4653
# 4         6.000          78

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

topRated = requests.get(url, headers=headers)
topRated = topRated.json()
nowTopRated = pd.DataFrame(topRated["results"])
nowTopRated.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 2  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 3  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en  The Shawshank Redemption
# 2                en             The Godfather
# 3                en     The Godfather Part II
# 4                en          Schindler's List
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  Imprisoned in the 1940s for the double murder ...     248.751
# 2  Spanning the years 1945 to 1955, a chronicle o...     238.182
# 3  In the continuing saga of the Corleone crime f...     113.914
# 4  The true story of how businessman Oskar Schind...      88.453
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 2  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 3  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20     The Godfather Part II
# 4  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15          Schindler's List
#
#    video  vote_average  vote_count
# 0  False         8.705        1069
# 1  False         8.707       26979
# 2  False         8.700       20492
# 3  False         8.600       12359
# 4  False         8.600       15767

# %%
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
}

upcoming = requests.get(url, headers=headers)
upcoming = upcoming.json()
nowUpcoming = pd.DataFrame(upcoming["results"])
nowUpcoming.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg      [14, 27, 28]  1087822
#
#   original_language            original_title  \
# 0                en            The Wild Robot
# 1                en             The Substance
# 2                en                    Azrael
# 3                en               Terrifier 3
# 4                en  Hellboy: The Crooked Man
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    7456.608
# 1  A fading celebrity decides to use a black mark...    4852.638
# 2  In a world where no one speaks, a devout femal...    2309.545
# 3  Five years after surviving Art the Clown's Hal...    1413.081
# 4  Hellboy and a rookie BPRD agent get stranded i...    1328.022
#
#                         poster_path release_date                     title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12            The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07             The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                    Azrael
# 3  /l1175hgL5DoXnqeZQCcU3eZIdhX.jpg   2024-10-09               Terrifier 3
# 4  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29  Hellboy: The Crooked Man
#
#    video  vote_average  vote_count
# 0  False         8.705        1069
# 1  False         7.300         722
# 2  False         6.000          78
# 3  False         7.000          94
# 4  False         4.982         142

# %%
ConDf = pd.concat([now, nowPopular, nowTopRated, nowUpcoming])

# %%
display(ConDf)
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg         [16, 878, 10751]  1184918
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg            [27, 18, 878]   933260
# 2   False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg             [28, 27, 53]  1029235
# 3   False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg            [878, 53, 18]  1125510
# 4   False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg             [35, 14, 27]   917496
# ..    ...                               ...                      ...      ...
# 15  False  /9juRmk8QjcsUcbrevVu5t8VZy5G.jpg         [28, 12, 80, 53]   923667
# 16  False  /h9YlRHAZWOWtGonllmj6JJg1FrE.jpg  [28, 12, 16, 10751, 14]   588648
# 17  False  /sjC29cgm4qZAnpOJQbYKCxDCcra.jpg            [27, 878, 53]  1062215
# 18  False  /AjTodtZJlQxycfRPktnUTpknblv.jpg      [16, 12, 35, 10751]  1207830
# 19  False  /hd1TvTUGjkoYoqvXYfSBpI5Ri9B.jpg        [16, 28, 12, 878]  1159311
#
#    original_language                      original_title  \
# 0                 en                      The Wild Robot
# 1                 en                       The Substance
# 2                 en                              Azrael
# 3                 es                           El hoyo 2
# 4                 en             Beetlejuice Beetlejuice
# ..               ...                                 ...
# 15                cn                             九龍城寨之圍城
# 16                zh                        Dragonkeeper
# 17                en                              Afraid
# 18                en  Gracie & Pedro: Pets to the Rescue
# 19                ja        僕のヒーローアカデミア THE MOVIE ユアネクスト
#
#                                              overview  popularity  \
# 0   After a shipwreck, an intelligent robot called...    7456.608
# 1   A fading celebrity decides to use a black mark...    4852.638
# 2   In a world where no one speaks, a devout femal...    2309.545
# 3   After a mysterious leader imposes his law in a...    1781.297
# 4   After a family tragedy, three generations of t...    2059.319
# ..                                                ...         ...
# 15  In 1980s Hong Kong, troubled youth Chan Lok-kw...     287.643
# 16  Set in Han Imperial China, the plot follows th...     338.237
# 17  Curtis Pike and his family are selected to tes...     253.566
# 18  Family frenemies, Gracie and Pedro, must put t...     289.478
# 19  In a society devastated by the effects of an a...     234.101
#
#                          poster_path release_date  \
# 0   /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12
# 1   /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07
# 2   /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27
# 3   /izuzUb0sDokqp9o8utVfsrSJuy5.jpg   2024-09-27
# 4   /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04
# ..                               ...          ...
# 15  /h0tunBO4tMjvKVVG7fXqHgwOr5C.jpg   2024-04-23
# 16  /ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg   2024-04-11
# 17  /gUREuXCnJLVHsvKXDH9fgIcfM6e.jpg   2024-08-28
# 18  /1agSI7NGvagr720za8XAubtqUoB.jpg   2024-05-01
# 19  /8rdB1wkheEMMqcY8qLAKjCMPcnZ.jpg   2024-08-02
#
#                                   title  video  vote_average  vote_count
# 0                        The Wild Robot  False         8.700        1060
# 1                         The Substance  False         7.300         718
# 2                                Azrael  False         6.000          78
# 3                        The Platform 2  False         5.700         645
# 4               Beetlejuice Beetlejuice  False         7.203        1445
# ..                                  ...    ...           ...         ...
# 15  Twilight of the Warriors: Walled In  False         6.500         190
# 16                         Dragonkeeper  False         7.300         113
# 17                               Afraid  False         6.250         222
# 18   Gracie & Pedro: Pets to the Rescue  False         7.000          20
# 19        My Hero Academia: You're Next  False         7.100          17
#
# [80 rows x 14 columns]

# %%
ConDf.drop_duplicates(subset=['id'], inplace=True)

# %%
ConDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              58 non-null     bool
#  1   backdrop_path      58 non-null     object
#  2   genre_ids          58 non-null     object
#  3   id                 58 non-null     int64
#  4   original_language  58 non-null     object
#  5   original_title     58 non-null     object
#  6   overview           58 non-null     object
#  7   popularity         58 non-null     float64
#  8   poster_path        58 non-null     object
#  9   release_date       58 non-null     object
#  10  title              58 non-null     object
#  11  video              58 non-null     bool
#  12  vote_average       58 non-null     float64
#  13  vote_count         58 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 6.0+ KB

# %%
def get_revenueBudget(df):
    '''uses the movie ID to get data from the "details" endpoint. Returns a dataframe of revenue and budget data.
    '''
    data = {
        "id": [], 
        "budget": [],
        "revenue": []
        
    }
    
    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MjhjNmM4MDlhYzM1ZTIxYzVhMTU1ZDkwZTQ4YzA1YSIsIm5iZiI6MTcyNzk3MDQwMi4zNTE3MzksInN1YiI6IjY2ZmViOWQ3OTI1ZmRmOTI1YjdjOTRmYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.veLjo0EXnEHCyjSz9crHkjbiYxz1vWEZF6rl34f-LLM"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        print(response)
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])

        
    return pd.DataFrame(data)

money = get_revenueBudget(ConDf)
print(ConDf.info())
# Out:
# {'adult': False, 'backdrop_path': '/417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg', 'belongs_to_collection': {'id': 1370345, 'name': 'The Wild Robot Collection', 'poster_path': None, 'backdrop_path': None}, 'budget': 78000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10751, 'name': 'Family'}], 'homepage': 'https://www.thewildrobotmovie.com', 'id': 1184918, 'imdb_id': 'tt29623480', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Wild Robot', 'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.", 'popularity': 7456.608, 'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg', 'production_companies': [{'id': 521, 'logo_path': '/3BPX5VGBov8SDqTV7wC1L1xShAS.png', 'name': 'DreamWorks Animation', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-12', 'revenue': 196822000, 'runtime': 102, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Discover your true nature.', 'title': 'The Wild Robot', 'video': False, 'vote_average': 8.7, 'vote_count': 1080}
# {'adult': False, 'backdrop_path': '/7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg', 'belongs_to_collection': None, 'budget': 17500000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 18, 'name': 'Drama'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': 'https://www.the-match-factory.com/catalogue/films/the-substance.html', 'id': 933260, 'imdb_id': 'tt17526714', 'origin_country': ['GB'], 'original_language': 'en', 'original_title': 'The Substance', 'overview': 'A fading celebrity decides to use a black market drug, a cell-replicating substance that temporarily creates a younger, better version of herself.', 'popularity': 4852.638, 'poster_path': '/lqoMzCcZYEFK729d6qzt349fB4o.jpg', 'production_companies': [{'id': 10163, 'logo_path': '/16KWBMmfPX0aJzDExDrPxSLj0Pg.png', 'name': 'Working Title Films', 'origin_country': 'GB'}, {'id': 233939, 'logo_path': None, 'name': 'Blacksmith', 'origin_country': 'FR'}], 'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}], 'release_date': '2024-09-07', 'revenue': 29106531, 'runtime': 141, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'If you follow the instructions, what could go wrong?', 'title': 'The Substance', 'video': False, 'vote_average': 7.3, 'vote_count': 718}
# {'adult': False, 'backdrop_path': '/4KHEK6AQFHhv4TDtL3KLReePB05.jpg', 'belongs_to_collection': None, 'budget': 12000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': '', 'id': 1029235, 'imdb_id': 'tt22173666', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Azrael', 'overview': 'In a world where no one speaks, a devout female hunts down a young woman who has escaped her imprisonment. Recaptured by its ruthless leaders, Azrael is due to be sacrificed to pacify an ancient evil deep within the surrounding wilderness.', 'popularity': 2309.545, 'poster_path': '/qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg', 'production_companies': [{'id': 184518, 'logo_path': '/lOouI8ibBzhLI4qvku74FPUVT8t.png', 'name': 'C2 Motion Picture Group', 'origin_country': 'US'}, {'id': 6144, 'logo_path': '/iarVMSGDqo8sAHPxz6duesUBRXG.png', 'name': 'Homeless Bob Production', 'origin_country': 'EE'}, {'id': 232289, 'logo_path': None, 'name': 'Traffic.', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'EE', 'name': 'Estonia'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-27', 'revenue': 0, 'runtime': 86, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Many years after the rapture… Among the survivors, some are driven to renounce their sin of Speech.', 'title': 'Azrael', 'video': False, 'vote_average': 6.0, 'vote_count': 78}
# {'adult': False, 'backdrop_path': '/3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg', 'belongs_to_collection': {'id': 1126392, 'name': 'The Platform Collection', 'poster_path': '/nhzz8k3Kh1roYdPvbryX3VtgLZN.jpg', 'backdrop_path': '/m7REj1vsxi2aEcwT7iFHPRXbwgN.jpg'}, 'budget': 0, 'genres': [{'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}], 'homepage': 'https://www.netflix.com/title/81284730', 'id': 1125510, 'imdb_id': 'tt27729779', 'origin_country': ['ES'], 'original_language': 'es', 'original_title': 'El hoyo 2', 'overview': 'After a mysterious leader imposes his law in a brutal system of vertical cells, a new arrival battles against a dubious food distribution method.', 'popularity': 1781.297, 'poster_path': '/izuzUb0sDokqp9o8utVfsrSJuy5.jpg', 'production_companies': [{'id': 52270, 'logo_path': None, 'name': 'Basque Films', 'origin_country': 'ES'}], 'production_countries': [{'iso_3166_1': 'ES', 'name': 'Spain'}], 'release_date': '2024-09-27', 'revenue': 0, 'runtime': 100, 'spoken_languages': [{'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'status': 'Released', 'tagline': '', 'title': 'The Platform 2', 'video': False, 'vote_average': 5.672, 'vote_count': 645}
# {'adult': False, 'backdrop_path': '/xi1VSt3DtkevUmzCx2mNlCoDe74.jpg', 'belongs_to_collection': {'id': 945475, 'name': 'Beetlejuice Collection', 'poster_path': '/2N5c3ue4bxvTO5OO3bOjHPJZs3H.jpg', 'backdrop_path': '/bJ76WnTj7G8dYQSZJvZejna262D.jpg'}, 'budget': 100000000, 'genres': [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}], 'homepage': 'https://www.beetlejuicemovie.com', 'id': 917496, 'imdb_id': 'tt2049403', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Beetlejuice Beetlejuice', 'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Betelgeuse, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.", 'popularity': 2059.319, 'poster_path': '/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 360, 'logo_path': '/hbDlIbBdBe0nVFTeZ7hDX3d5n2N.png', 'name': 'Geffen Pictures', 'origin_country': 'US'}, {'id': 81, 'logo_path': '/8wOfUhA7vwU2gbPjQy7Vv3EiF0o.png', 'name': 'Plan B Entertainment', 'origin_country': 'US'}, {'id': 8601, 'logo_path': '/kqubCH3sfBAk4znUj7hjqv8ffgi.png', 'name': 'Tim Burton Productions', 'origin_country': 'US'}, {'id': 216687, 'logo_path': None, 'name': 'Domain Entertainment', 'origin_country': 'US'}, {'id': 228708, 'logo_path': None, 'name': 'Tommy Harper Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-04', 'revenue': 434090643, 'runtime': 105, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Vietnamese', 'iso_639_1': 'vi', 'name': 'Tiếng Việt'}], 'status': 'Released', 'tagline': 'The ghost with the most is back.', 'title': 'Beetlejuice Beetlejuice', 'video': False, 'vote_average': 7.206, 'vote_count': 1446}
# {'adult': False, 'backdrop_path': '/eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg', 'belongs_to_collection': {'id': 727761, 'name': 'Terrifier Collection', 'poster_path': '/4xIzrMcEvCzJm5qAl92WMHLSIeM.jpg', 'backdrop_path': '/zREjCmCHIHdEF6ufPoDQjhl4Wdm.jpg'}, 'budget': 2000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://terrifier3.com/', 'id': 1034541, 'imdb_id': 'tt27911000', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Terrifier 3', 'overview': "Five years after surviving Art the Clown's Halloween massacre, Sienna and Jonathan are still struggling to rebuild their shattered lives. As the holiday season approaches, they try to embrace the Christmas spirit and leave the horrors of the past behind. But just when they think they're safe, Art returns, determined to turn their holiday cheer into a new nightmare. The festive season quickly unravels as Art unleashes his twisted brand of terror, proving that no holiday is safe.", 'popularity': 1413.081, 'poster_path': '/l1175hgL5DoXnqeZQCcU3eZIdhX.jpg', 'production_companies': [{'id': 238902, 'logo_path': '/jLAg5fOlAw1Jl8Q7WoyKxh1H22y.png', 'name': 'Cineverse', 'origin_country': 'US'}, {'id': 15157, 'logo_path': '/yezzLb9RbKNtQUsyYySAqC9TQr7.png', 'name': 'Bloody Disgusting', 'origin_country': 'US'}, {'id': 84591, 'logo_path': None, 'name': 'Dark Age Cinema', 'origin_country': 'US'}, {'id': 114220, 'logo_path': '/b5n3DtfUySREkq4Xi962zMg69qq.png', 'name': 'Fuzz on the Lens Productions', 'origin_country': 'US'}, {'id': 213025, 'logo_path': '/bFz17QGqfF8wiQAH3T4kfzKC8dU.png', 'name': 'The Coven', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-09', 'revenue': 41267606, 'runtime': 125, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'You better not shout, you better not cry.', 'title': 'Terrifier 3', 'video': False, 'vote_average': 7.032, 'vote_count': 94}
# {'adult': False, 'backdrop_path': '/g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://millennium-media.net/mf-films/hellboy-crooked-man', 'id': 1087822, 'imdb_id': 'tt26757462', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Hellboy: The Crooked Man', 'overview': "Hellboy and a rookie BPRD agent get stranded in 1950s rural Appalachia. There, they discover a small community haunted by witches, led by a local devil with a troubling connection to Hellboy's past: the Crooked Man.", 'popularity': 1328.022, 'poster_path': '/iz2GabtToVB05gLTVSH7ZvFtsMM.jpg', 'production_companies': [{'id': 552, 'logo_path': '/9dGdLfm3GteWeUDtD9c9tvlidUG.png', 'name': 'Dark Horse Entertainment', 'origin_country': 'US'}, {'id': 1020, 'logo_path': '/kuUIHNwMec4dwOLghDhhZJzHZTd.png', 'name': 'Millennium Media', 'origin_country': 'US'}, {'id': 823, 'logo_path': '/275O5OoKjulWtY1uRHRXaYsrt9I.png', 'name': 'Telepool', 'origin_country': 'DE'}], 'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-29', 'revenue': 1289658, 'runtime': 100, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Something crooked this way comes.', 'title': 'Hellboy: The Crooked Man', 'video': False, 'vote_average': 5.0, 'vote_count': 142}
# {'adult': False, 'backdrop_path': '/AaYdXkEqExgG66p55J677Qnagpf.jpg', 'belongs_to_collection': {'id': 1100788, 'name': 'Smile Collection', 'poster_path': '/a5minNPeyarx7mgFfBjJPUgShys.jpg', 'backdrop_path': '/vvmx7xovzaK262VKksh72G2T1bi.jpg'}, 'budget': 28000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}], 'homepage': 'https://www.smile.movie', 'id': 1100782, 'imdb_id': 'tt29268110', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Smile 2', 'overview': 'About to embark on a new world tour, global pop sensation Skye Riley begins experiencing increasingly terrifying and inexplicable events. Overwhelmed by the escalating horrors and the pressures of fame, Skye is forced to face her dark past to regain control of her life before it spirals out of control.', 'popularity': 998.028, 'poster_path': '/aE85MnPIsSoSs3978Noo16BRsKN.jpg', 'production_companies': [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png', 'name': 'Paramount Pictures', 'origin_country': 'US'}, {'id': 12292, 'logo_path': '/4GQTeqos2luopEtp3OgMQYusQ5c.png', 'name': 'Temple Hill Entertainment', 'origin_country': 'US'}, {'id': 231315, 'logo_path': None, 'name': 'Bad Feeling', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-16', 'revenue': 46000000, 'runtime': 127, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': "It's the last thing you'll see.", 'title': 'Smile 2', 'video': False, 'vote_average': 7.1, 'vote_count': 93}
# {'adult': False, 'backdrop_path': '/l8OyAXEp5FKZWmDhqJMbiwAEvz.jpg', 'belongs_to_collection': None, 'budget': 20000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 18, 'name': 'Drama'}], 'homepage': 'https://www.neverletgo.movie', 'id': 814889, 'imdb_id': 'tt14415204', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Never Let Go', 'overview': 'As an evil takes over the world beyond their front doorstep, the only protection for a mother and her twin sons is their house and their family’s protective bond.', 'popularity': 1106.53, 'poster_path': '/3EpZ2ksjijmdr8BhISP03PYzNFW.jpg', 'production_companies': [{'id': 1632, 'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png', 'name': 'Lionsgate', 'origin_country': 'US'}, {'id': 2575, 'logo_path': '/9YJrHYlcfHtwtulkFMAies3aFEl.png', 'name': '21 Laps Entertainment', 'origin_country': 'US'}, {'id': 221429, 'logo_path': None, 'name': 'Media Capital Technologies', 'origin_country': 'US'}, {'id': 211864, 'logo_path': None, 'name': 'HalleHolly', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-18', 'revenue': 13111608, 'runtime': 101, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'One touch is all it takes.', 'title': 'Never Let Go', 'video': False, 'vote_average': 6.045, 'vote_count': 132}
# {'adult': False, 'backdrop_path': '/oAadr06zrHUQVKdZdgdBojRssPq.jpg', 'belongs_to_collection': {'id': 987044, 'name': 'Joker Collection', 'poster_path': '/jmopX21dlCinxmzd8KLOBFeN2P9.jpg', 'backdrop_path': '/k1YC7mFLvxX4bbD7P8lkcML0Jek.jpg'}, 'budget': 195000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://www.joker.movie', 'id': 889737, 'imdb_id': 'tt11315808', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Joker: Folie à Deux', 'overview': "While struggling with his dual identity, Arthur Fleck not only stumbles upon true love, but also finds the music that's always been inside him.", 'popularity': 934.071, 'poster_path': '/aciP8Km0waTLXEYf5ybFK5CSUxl.jpg', 'production_companies': [{'id': 174, 'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png', 'name': 'Warner Bros. Pictures', 'origin_country': 'US'}, {'id': 83036, 'logo_path': None, 'name': 'Joint Effort', 'origin_country': 'US'}, {'id': 216687, 'logo_path': None, 'name': 'Domain Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-01', 'revenue': 164959127, 'runtime': 138, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'The world is a stage.', 'title': 'Joker: Folie à Deux', 'video': False, 'vote_average': 5.826, 'vote_count': 887}
# {'adult': False, 'backdrop_path': '/uVWlwJebxX0M3axXAUrryJ6w9cQ.jpg', 'belongs_to_collection': None, 'budget': 30000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://www.thekillersgame.movie/', 'id': 507241, 'imdb_id': 'tt0327785', 'origin_country': ['US'], 'original_language': 'en', 'original_title': "The Killer's Game", 'overview': "When top hitman Joe Flood is diagnosed with a terminal illness, he decides to take matters into his own hands – by taking a hit out on himself. But when the very hitmen he hired also target his ex-girlfriend, he must fend off an army of assassin colleagues and win back the love of his life before it's too late.", 'popularity': 812.402, 'poster_path': '/4bKlTeOUr5AKrLky8mwWvlQqyVd.jpg', 'production_companies': [{'id': 47729, 'logo_path': '/bAxh897TGgdR0Py6wdd0UuE147Z.png', 'name': 'STXfilms', 'origin_country': 'US'}, {'id': 183234, 'logo_path': None, 'name': 'Dogbone Entertainment', 'origin_country': 'US'}, {'id': 1757, 'logo_path': '/fc9qw5GoTbyWGa0QcfbsZFzuMKQ.png', 'name': 'Mad Chance', 'origin_country': 'US'}, {'id': 89171, 'logo_path': '/c3ttVfx0itQzk2vOR0053qzzd3B.png', 'name': 'Endurance Media', 'origin_country': 'US'}, {'id': 175316, 'logo_path': '/jB6FmRiPnKGHWSfk46iwjH38CRU.png', 'name': 'K. JAM Media', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-09-12', 'revenue': 5090881, 'runtime': 104, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Winning is all in the execution.', 'title': "The Killer's Game", 'video': False, 'vote_average': 6.343, 'vote_count': 67}
# {'adult': False, 'backdrop_path': '/hPIWQT70wQK6akqfLXByEvr62u0.jpg', 'belongs_to_collection': None, 'budget': 14750000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': '', 'id': 726139, 'imdb_id': 'tt25808194', 'origin_country': ['KR'], 'original_language': 'ko', 'original_title': '탈출: 프로젝트 사일런스', 'overview': 'Due to sudden deteriorating weather conditions, visibility on the Airport Bridge is severely impaired, leaving people stranded and at risk of the bridge collapsing due to a series of chain collisions and explosions. Amidst the chaos, the canine subjects "Echo" from the military experiment "Project Silence," who were being transported in secret, break free, and all human survivors become targets of relentless attacks.', 'popularity': 1015.834, 'poster_path': '/fttoFfKikQMwIoV3UVvlCvBhbUw.jpg', 'production_companies': [{'id': 147142, 'logo_path': '/2PLXkCFStjT8Quq3DeDj9dVbM5j.png', 'name': 'Blaad Studios', 'origin_country': 'KR'}, {'id': 128404, 'logo_path': '/dP3usmr6di1jMPH738rvbxdkmSQ.png', 'name': 'CJ ENM', 'origin_country': 'KR'}, {'id': 199265, 'logo_path': '/mv2yDqAgT1ea1eTXZMDr89zX95M.png', 'name': 'CJ ENM Studios', 'origin_country': 'KR'}, {'id': 7036, 'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png', 'name': 'CJ Entertainment', 'origin_country': 'KR'}], 'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}], 'release_date': '2024-07-11', 'revenue': 0, 'runtime': 96, 'spoken_languages': [{'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}], 'status': 'Released', 'tagline': 'Every survivor is a target.', 'title': 'Project Silence', 'video': False, 'vote_average': 7.051, 'vote_count': 185}
# {'adult': False, 'backdrop_path': '/Asg2UUwipAdE87MxtJy7SQo08XI.jpg', 'belongs_to_collection': None, 'budget': 50000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 14, 'name': 'Fantasy'}, {'id': 27, 'name': 'Horror'}], 'homepage': 'https://thecrow.movie/', 'id': 957452, 'imdb_id': 'tt1340094', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Crow', 'overview': 'Soulmates Eric and Shelly are brutally murdered when the demons of her dark past catch up with them. Given the chance to save his true love by sacrificing himself, Eric sets out to seek merciless revenge on their killers, traversing the worlds of the living and the dead to put the wrong things right.', 'popularity': 922.574, 'poster_path': '/58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg', 'production_companies': [{'id': 342, 'logo_path': '/kZ99mxyNvNgyAFjm7rcl9vfYmU8.png', 'name': 'Davis Films', 'origin_country': 'FR'}, {'id': 6455, 'logo_path': '/mc3rMk0tW5ajjbfqkB8xlp85Cdy.png', 'name': 'Pressman Film', 'origin_country': 'US'}, {'id': 51526, 'logo_path': None, 'name': 'Hassell Free Production', 'origin_country': 'US'}, {'id': 67260, 'logo_path': '/oV2FZfhRcEc1HReC66e1L4t2qPV.png', 'name': 'The Electric Shadow Company', 'origin_country': 'GB'}, {'id': 104363, 'logo_path': '/tKIimrvYUH02D4km00lCEDUYvIF.png', 'name': '30WEST', 'origin_country': 'US'}, {'id': 189103, 'logo_path': '/hu0qcD4k7kfWpdAewqmJSUyZPa7.png', 'name': 'Ashland Hill Media Finance', 'origin_country': 'US'}, {'id': 7493, 'logo_path': '/fHitYiGUCkRafgt6VPYQlXWLkdp.png', 'name': 'FilmNation Entertainment', 'origin_country': 'US'}, {'id': 112609, 'logo_path': '/9lpuWYlMInFARjrNUhVAzBW2YzT.png', 'name': 'Maze Pictures', 'origin_country': 'DE'}, {'id': 25838, 'logo_path': None, 'name': 'Occupant Entertainment', 'origin_country': 'DE'}], 'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-21', 'revenue': 13690814, 'runtime': 111, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'True love never dies.', 'title': 'The Crow', 'video': False, 'vote_average': 5.824, 'vote_count': 654}
# {'adult': False, 'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg', 'belongs_to_collection': {'id': 558216, 'name': 'Venom Collection', 'poster_path': '/hoTLlTIohrzQ13HQVkZrDlvffuT.jpg', 'backdrop_path': '/vq340s8DxA5Q209FT8PHA6CXYOx.jpg'}, 'budget': 110000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 12, 'name': 'Adventure'}], 'homepage': 'https://venom.movie', 'id': 912649, 'imdb_id': 'tt16366836', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Venom: The Last Dance', 'overview': "Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.", 'popularity': 947.495, 'poster_path': '/aosm8NMQ3UyoBVpSxyimorCQykC.jpg', 'production_companies': [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 53462, 'logo_path': '/nx8B3Phlcse02w86RW4CJqzCnfL.png', 'name': 'Matt Tolmach Productions', 'origin_country': 'US'}, {'id': 91797, 'logo_path': None, 'name': 'Hutch Parker Entertainment', 'origin_country': 'US'}, {'id': 14439, 'logo_path': None, 'name': 'Arad Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-22', 'revenue': 0, 'runtime': 109, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': "'Til death do they part.", 'title': 'Venom: The Last Dance', 'video': False, 'vote_average': 7.4, 'vote_count': 10}
# {'adult': False, 'backdrop_path': '/cRdA9xjHBbobw4LJFsQ3j1CgpVq.jpg', 'belongs_to_collection': {'id': 727761, 'name': 'Terrifier Collection', 'poster_path': '/4xIzrMcEvCzJm5qAl92WMHLSIeM.jpg', 'backdrop_path': '/zREjCmCHIHdEF6ufPoDQjhl4Wdm.jpg'}, 'budget': 250000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'http://www.terrifier2themovie.com/', 'id': 663712, 'imdb_id': 'tt10403420', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Terrifier 2', 'overview': "A year after the Miles County massacre, Art the Clown is resurrected by a sinister entity. Art returns home, where he must hunt down and destroy teenage Sienna and her younger brother Jonathan on Halloween. As the body count rises, the siblings fight to stay alive while uncovering the true nature of Art's evil intent.", 'popularity': 720.573, 'poster_path': '/8gLhu8UFPZfH2Hv11JhTZkb9CVl.jpg', 'production_companies': [{'id': 84591, 'logo_path': None, 'name': 'Dark Age Cinema', 'origin_country': 'US'}, {'id': 114220, 'logo_path': '/b5n3DtfUySREkq4Xi962zMg69qq.png', 'name': 'Fuzz on the Lens Productions', 'origin_country': 'US'}, {'id': 15157, 'logo_path': '/yezzLb9RbKNtQUsyYySAqC9TQr7.png', 'name': 'Bloody Disgusting', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2022-10-06', 'revenue': 15740003, 'runtime': 138, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': "Who's laughing now?", 'title': 'Terrifier 2', 'video': False, 'vote_average': 6.772, 'vote_count': 1857}
# {'adult': False, 'backdrop_path': '/vGaBqgY8YRzQVUbBMPnd5SmYvL7.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://www.netflix.com/title/81686326', 'id': 1329336, 'imdb_id': 'tt33130902', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Bad Guys: Haunted Heist', 'overview': 'The crafty Bad Guys crew embarks on a high-stakes Halloween heist to swipe a priceless amulet from a spooky mansion. What could go wrong?', 'popularity': 674.301, 'poster_path': '/oEJC05CqPugMxC4rFu9r6r6vg6m.jpg', 'production_companies': [{'id': 42141, 'logo_path': '/3DWUezrpxTqVMW4oKRhzfqJbULK.png', 'name': 'DreamWorks Animation Television', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-02', 'revenue': 0, 'runtime': 25, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'The Bad Guys: Haunted Heist', 'video': False, 'vote_average': 7.41, 'vote_count': 61}
# {'adult': False, 'backdrop_path': '/64tinBsds1nVp4wOCgYhMbSgsRW.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}], 'homepage': 'https://www.netflix.com/title/81672158', 'id': 1075676, 'imdb_id': 'tt27987046', 'origin_country': ['KR'], 'original_language': 'ko', 'original_title': '전,란', 'overview': 'In the Joseon Dynasty, two friends who grew up together — one the master and one the servant — reunite post-war as enemies on opposing sides.', 'popularity': 850.531, 'poster_path': '/hg9OeaCRSpazrfqYyEFr6BDaZW8.jpg', 'production_companies': [{'id': 34725, 'logo_path': '/cRqXC6Dy6AvTGS2wiMt26yGJgZA.png', 'name': 'Moho Film', 'origin_country': 'KR'}, {'id': 126933, 'logo_path': '/b4Qf4nZDudPjUvnLqu3DzeHWdzh.png', 'name': 'Semicolon Studio', 'origin_country': 'KR'}], 'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}], 'release_date': '2024-10-02', 'revenue': 0, 'runtime': 126, 'spoken_languages': [{'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}, {'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}], 'status': 'Released', 'tagline': 'An era of chaos, a battle against destiny', 'title': 'Uprising', 'video': False, 'vote_average': 7.3, 'vote_count': 62}
# {'adult': False, 'backdrop_path': '/vmzauGqSgx25rzavUbuN6c5Vdfc.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}], 'homepage': 'https://www.inseparablesmovie.com', 'id': 1059264, 'imdb_id': 'tt20221460', 'origin_country': ['BE', 'ES', 'FR'], 'original_language': 'en', 'original_title': 'The Inseparables', 'overview': 'The animated buddy movie follows the misadventures of Don, a runaway puppet with boundless imaginations, and DJ Doggy Dog, an abandoned plush looking for a friend, who cross paths in Central Park and team up against all odds for a epic friendship adventure in New York.', 'popularity': 657.279, 'poster_path': '/dmftU2Rnmv9KTteMUwjalOuZHke.jpg', 'production_companies': [{'id': 10159, 'logo_path': None, 'name': 'nWave Pictures', 'origin_country': 'BE'}, {'id': 146118, 'logo_path': None, 'name': 'Octopolis', 'origin_country': 'FR'}, {'id': 33916, 'logo_path': '/xeBwba4AfwmDaBGG0ok1MzLJZrn.png', 'name': 'A Contracorriente Films', 'origin_country': 'ES'}], 'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'}, {'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'ES', 'name': 'Spain'}], 'release_date': '2023-09-01', 'revenue': 311198, 'runtime': 90, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Friendship is the greatest adventure.', 'title': 'The Inseparables', 'video': False, 'vote_average': 6.6, 'vote_count': 26}
# {'adult': False, 'backdrop_path': '/7cjrEMDo2xDT95fvCNb0CssokxZ.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://www.disneyplus.com/movies/the-most-wonderful-time-of-the-year/4xqSSPhvz6Xw', 'id': 1358947, 'imdb_id': 'tt33797186', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Most Wonderful Time of the Year', 'overview': 'Sideshow Bob teams up with the most infamous villains of Disney+ to share the true meaning of the Halloween season. Filled with music, mayhem, and madness, this short from "The Simpsons" is simply to die for.', 'popularity': 632.149, 'poster_path': '/3ivqP56Jd8RkbDidoe1rGFVGpJZ.jpg', 'production_companies': [{'id': 154887, 'logo_path': '/wLFPu95hIMmyLR5hdtvYaMuK0tG.png', 'name': '20th Television Animation', 'origin_country': 'US'}, {'id': 18, 'logo_path': '/uqhagSwM7NAkQWVCQhKTyoqF8XH.png', 'name': 'Gracie Films', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-11', 'revenue': 0, 'runtime': 3, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'The Most Wonderful Time of the Year', 'video': False, 'vote_average': 5.4, 'vote_count': 11}
# {'adult': False, 'backdrop_path': '/AowNXLFNKWDRYBKHLsgTK0T7Bxf.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://www.netflix.com/title/81727408', 'id': 1210794, 'imdb_id': 'tt30217143', 'origin_country': ['SE'], 'original_language': 'sv', 'original_title': 'Strul', 'overview': 'Wrongfully convicted of murder, a clumsy electronics salesman faces police corruption and criminal conspiracies in an attempt to prove his innocence.', 'popularity': 647.417, 'poster_path': '/ildbg7ho14EHbt1fZWAkgqIyPqy.jpg', 'production_companies': [{'id': 25297, 'logo_path': '/eBEOs6T0nVa8RKWmZbBWIvc4daL.png', 'name': 'FLX', 'origin_country': 'SE'}], 'production_countries': [{'iso_3166_1': 'SE', 'name': 'Sweden'}], 'release_date': '2024-10-02', 'revenue': 0, 'runtime': 98, 'spoken_languages': [{'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'}], 'status': 'Released', 'tagline': 'It gets complicated.', 'title': 'Trouble', 'video': False, 'vote_average': 6.9, 'vote_count': 92}
# {'adult': False, 'backdrop_path': '/9SSEUrSqhljBMzRe4aBTh17rUaC.jpg', 'belongs_to_collection': None, 'budget': 80000000, 'genres': [{'id': 878, 'name': 'Science Fiction'}, {'id': 27, 'name': 'Horror'}], 'homepage': 'https://www.20thcenturystudios.com/movies/alien-romulus', 'id': 945961, 'imdb_id': 'tt18412256', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Alien: Romulus', 'overview': 'While scavenging the deep ends of a derelict space station, a group of young space colonizers come face to face with the most terrifying life form in the universe.', 'popularity': 6369.381, 'poster_path': '/b33nnKl1GSFbao4l3fZDDqsMx0F.jpg', 'production_companies': [{'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png', 'name': '20th Century Studios', 'origin_country': 'US'}, {'id': 221347, 'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png', 'name': 'Scott Free Productions', 'origin_country': 'US'}, {'id': 401, 'logo_path': '/t7mM3DvQ9MwDT3YzMCBrkWpWiiz.png', 'name': 'Brandywine Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-13', 'revenue': 348521150, 'runtime': 119, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'In space, no one can hear you.', 'title': 'Alien: Romulus', 'video': False, 'vote_average': 7.3, 'vote_count': 1713}
# {'adult': False, 'backdrop_path': '/yDHYTfA3R0jFYba16jBB1ef8oIt.jpg', 'belongs_to_collection': {'id': 448150, 'name': 'Deadpool Collection', 'poster_path': '/30c5jO7YEXuF8KiWXLg9m28GWDA.jpg', 'backdrop_path': '/hBQOWY8qWXJVFAc8yLTh1teIu43.jpg'}, 'budget': 200000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': 'https://www.marvel.com/movies/deadpool-and-wolverine', 'id': 533535, 'imdb_id': 'tt6263850', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Deadpool & Wolverine', 'overview': 'A listless Wade Wilson toils away in civilian life with his days as the morally flexible mercenary, Deadpool, behind him. But when his homeworld faces an existential threat, Wade must reluctantly suit-up again with an even more reluctant Wolverine.', 'popularity': 2958.871, 'poster_path': '/8cdWjvZQUExUUTzyp4t6EDMubfO.jpg', 'production_companies': [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png', 'name': 'Marvel Studios', 'origin_country': 'US'}, {'id': 104228, 'logo_path': '/hx0C1XcSxGgat8N62GpxoJGTkCk.png', 'name': 'Maximum Effort', 'origin_country': 'US'}, {'id': 2575, 'logo_path': '/9YJrHYlcfHtwtulkFMAies3aFEl.png', 'name': '21 Laps Entertainment', 'origin_country': 'US'}, {'id': 127928, 'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png', 'name': '20th Century Studios', 'origin_country': 'US'}, {'id': 176762, 'logo_path': None, 'name': 'Kevin Feige Productions', 'origin_country': 'US'}, {'id': 22213, 'logo_path': '/qx9K6bFWJupwde0xQDwOvXkOaL8.png', 'name': 'TSG Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-07-24', 'revenue': 1334640330, 'runtime': 128, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Come together.', 'title': 'Deadpool & Wolverine', 'video': False, 'vote_average': 7.7, 'vote_count': 4660}
# {'adult': False, 'backdrop_path': '/lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg', 'belongs_to_collection': {'id': 86066, 'name': 'Despicable Me Collection', 'poster_path': '/95prV91f4DxkBnLU43YjLbU1m3q.jpg', 'backdrop_path': '/37xamYKRUGCRux532lKcZdVGYuR.jpg'}, 'budget': 100000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://www.despicable.me', 'id': 519182, 'imdb_id': 'tt7510222', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Despicable Me 4', 'overview': 'Gru and Lucy and their girls—Margo, Edith and Agnes—welcome a new member to the Gru family, Gru Jr., who is intent on tormenting his dad. Gru also faces a new nemesis in Maxime Le Mal and his femme fatale girlfriend Valentina, forcing the family to go on the run.', 'popularity': 1696.668, 'poster_path': '/wWba3TaojhK7NdycRhoQpsG0FaH.jpg', 'production_companies': [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 6704, 'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png', 'name': 'Illumination', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-06-20', 'revenue': 953140610, 'runtime': 94, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Things just got a little more despicable.', 'title': 'Despicable Me 4', 'video': False, 'vote_average': 7.121, 'vote_count': 2018}
# {'adult': False, 'backdrop_path': '/p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg', 'belongs_to_collection': {'id': 1022790, 'name': 'Inside Out Collection', 'poster_path': '/kvJqs0vm29U0xJa373wlzHb3FRh.jpg', 'backdrop_path': '/7U2m2dMSIfHx2gWXKq78Xj1weuH.jpg'}, 'budget': 200000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}], 'homepage': 'https://movies.disney.com/inside-out-2', 'id': 1022789, 'imdb_id': 'tt22022452', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Inside Out 2', 'overview': "Teenager Riley's mind headquarters is undergoing a sudden demolition to make room for something entirely unexpected: new Emotions! Joy, Sadness, Anger, Fear and Disgust, who’ve long been running a successful operation by all accounts, aren’t sure how to feel when Anxiety shows up. And it looks like she’s not alone.", 'popularity': 1433.487, 'poster_path': '/vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg', 'production_companies': [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png', 'name': 'Walt Disney Pictures', 'origin_country': 'US'}, {'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png', 'name': 'Pixar', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-06-11', 'revenue': 1682636477, 'runtime': 97, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Make room for new emotions.', 'title': 'Inside Out 2', 'video': False, 'vote_average': 7.619, 'vote_count': 4402}
# {'adult': False, 'backdrop_path': '/tCKWksaQI8XkAQLVou0AlGab5S6.jpg', 'belongs_to_collection': {'id': 814221, 'name': 'Transmorphers Collection', 'poster_path': None, 'backdrop_path': None}, 'budget': 0, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': 'http://theasylum.cc/', 'id': 1144962, 'imdb_id': 'tt28096092', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Transmorphers: Mech Beasts', 'overview': '20 years after the events of Transmorphers, a newer, more advanced species of alien robot descends on a rebuilt Earth, threatening once again to destroy the planet.', 'popularity': 1000.274, 'poster_path': '/oqhaffnQqSzdLrYAQA5W4IdAoCX.jpg', 'production_companies': [{'id': 1311, 'logo_path': '/ic2bTizdzRLDVzAvN7MXdUg3WQV.png', 'name': 'The Asylum', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2023-06-09', 'revenue': 65452, 'runtime': 84, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Metal mayhem!', 'title': 'Transmorphers: Mech Beasts', 'video': False, 'vote_average': 5.3, 'vote_count': 26}
# {'adult': False, 'backdrop_path': '/9msuazXGWAyl7vhxVFU7e7Bb5Ik.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}], 'homepage': '', 'id': 179387, 'imdb_id': 'tt1433524', 'origin_country': ['PH'], 'original_language': 'tl', 'original_title': 'Heavenly Touch', 'overview': 'Jonard is having trouble making ends meet. His mother is suffering from depression, and he and his sister are forced to quit school in order to take care of her. One day, Jonard meets up his friend Rodel, and Rodel introduces him to the world of massage parlors. Rodel teaches him massage, and brings him to Heavenly Touch, a syndicate-run massage parlor that mostly caters to homosexuals.', 'popularity': 894.379, 'poster_path': '/ory8WuAqznTE7lfopTSymHpop2t.jpg', 'production_companies': [{'id': 37558, 'logo_path': None, 'name': 'DMV Entertainment', 'origin_country': 'PH'}], 'production_countries': [{'iso_3166_1': 'PH', 'name': 'Philippines'}], 'release_date': '2009-05-12', 'revenue': 0, 'runtime': 89, 'spoken_languages': [{'english_name': 'Tagalog', 'iso_639_1': 'tl', 'name': ''}], 'status': 'Released', 'tagline': 'Feel the love. Feel the passion. Feel the pleasure.', 'title': 'Heavenly Touch', 'video': False, 'vote_average': 6.0, 'vote_count': 19}
# {'adult': False, 'backdrop_path': '/naNXYdBzTEb1KwOdi1RbBkM9Zv1.jpg', 'belongs_to_collection': {'id': 727761, 'name': 'Terrifier Collection', 'poster_path': '/4xIzrMcEvCzJm5qAl92WMHLSIeM.jpg', 'backdrop_path': '/zREjCmCHIHdEF6ufPoDQjhl4Wdm.jpg'}, 'budget': 35000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'http://terrifier3.com', 'id': 420634, 'imdb_id': 'tt4281724', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Terrifier', 'overview': 'A maniacal clown named Art terrorizes three young women on Halloween night and everyone else who stands in his way.', 'popularity': 741.604, 'poster_path': '/6PQqC4SbY910VvyVad6mvsboILU.jpg', 'production_companies': [{'id': 84591, 'logo_path': None, 'name': 'Dark Age Cinema', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2018-01-25', 'revenue': 416322, 'runtime': 85, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'You never forget your first kill.', 'title': 'Terrifier', 'video': False, 'vote_average': 6.431, 'vote_count': 2177}
# {'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'belongs_to_collection': None, 'budget': 25000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}], 'homepage': '', 'id': 278, 'imdb_id': 'tt0111161', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 248.751, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'production_companies': [{'id': 97, 'logo_path': '/7znWcbDd4PcJzJUlJxYqAlPPykp.png', 'name': 'Castle Rock Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '1994-09-23', 'revenue': 28341469, 'runtime': 142, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Fear can hold you prisoner. Hope can set you free.', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.707, 'vote_count': 26979}
# {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'belongs_to_collection': {'id': 230, 'name': 'The Godfather Collection', 'poster_path': '/zqV8MGXfpLZiFVObLxpAI7wWonJ.jpg', 'backdrop_path': '/mDMCET9Ens5ANvZAWRpluBsMAtS.jpg'}, 'budget': 6000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'http://www.thegodfather.com/', 'id': 238, 'imdb_id': 'tt0068646', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.', 'popularity': 238.182, 'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg', 'production_companies': [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png', 'name': 'Paramount Pictures', 'origin_country': 'US'}, {'id': 10211, 'logo_path': None, 'name': 'Alfran Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '1972-03-14', 'revenue': 245066411, 'runtime': 175, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}, {'english_name': 'Latin', 'iso_639_1': 'la', 'name': 'Latin'}], 'status': 'Released', 'tagline': "An offer you can't refuse.", 'title': 'The Godfather', 'video': False, 'vote_average': 8.7, 'vote_count': 20492}
# {'adult': False, 'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg', 'belongs_to_collection': {'id': 230, 'name': 'The Godfather Collection', 'poster_path': '/zqV8MGXfpLZiFVObLxpAI7wWonJ.jpg', 'backdrop_path': '/mDMCET9Ens5ANvZAWRpluBsMAtS.jpg'}, 'budget': 13000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}], 'homepage': '', 'id': 240, 'imdb_id': 'tt0071562', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Godfather Part II', 'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.', 'popularity': 113.914, 'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg', 'production_companies': [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UEN4CbHRc.png', 'name': 'Paramount Pictures', 'origin_country': 'US'}, {'id': 536, 'logo_path': None, 'name': 'The Coppola Company', 'origin_country': 'US'}, {'id': 70, 'logo_path': '/ueaENQkPcy8rlr5fGZVBXKOhlBh.png', 'name': 'American Zoetrope', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '1974-12-20', 'revenue': 102600000, 'runtime': 202, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}, {'english_name': 'Latin', 'iso_639_1': 'la', 'name': 'Latin'}, {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'status': 'Released', 'tagline': 'The rise and fall of the Corleone empire.', 'title': 'The Godfather Part II', 'video': False, 'vote_average': 8.6, 'vote_count': 12359}
# ...
# {'adult': False, 'backdrop_path': '/ujkVmpItWDLSkDCc7flsPywJhle.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 27, 'name': 'Horror'}], 'homepage': 'https://umbrellaent.com.au/movie/demon-disorder/', 'id': 1128941, 'imdb_id': 'tt27424585', 'origin_country': ['AU'], 'original_language': 'en', 'original_title': 'The Demon Disorder', 'overview': 'The pasts of three brothers and their deceased father collide when a deep, dark family secret is unearthed, leading to a case of revenge from beyond the grave.', 'popularity': 496.038, 'poster_path': '/Oqlmo1bhDQWWBPrMxMauuHL7y7.jpg', 'production_companies': [{'id': 142877, 'logo_path': '/c0Qhy9uvdXfvAZQ9e8GnT5Nb75m.png', 'name': 'Shudder', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'AU', 'name': 'Australia'}], 'release_date': '2024-08-16', 'revenue': 0, 'runtime': 86, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'There is no cure.', 'title': 'The Demon Disorder', 'video': False, 'vote_average': 5.6, 'vote_count': 21}
# {'adult': False, 'backdrop_path': '/jf1V00dZdNkVfEq7VPk8frrlELk.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'name': 'Mystery'}], 'homepage': 'https://www.max.com/movies/salems-lot/b1aaea47-b2e8-4418-a181-91de7102d04f', 'id': 748230, 'imdb_id': 'tt10245072', 'origin_country': ['US'], 'original_language': 'en', 'original_title': "Salem's Lot", 'overview': "Author Ben Mears returns to his childhood home of Jerusalem's Lot only to discover his hometown is being preyed upon by a bloodthirsty vampire.", 'popularity': 376.563, 'poster_path': '/j7ncdqBVufydVzVtxmXu8Ago4ox.jpg', 'production_companies': [{'id': 12, 'logo_path': '/2ycs64eqV5rqKYHyQK0GVoKGvfX.png', 'name': 'New Line Cinema', 'origin_country': 'US'}, {'id': 76907, 'logo_path': '/ygMQtjsKX7BZkCQhQZY82lgnCUO.png', 'name': 'Atomic Monster', 'origin_country': 'US'}, {'id': 829, 'logo_path': '/aXqwCvJSCDbTclkxAYfsT1l4Dsa.png', 'name': 'Vertigo Entertainment', 'origin_country': 'US'}, {'id': 2428, 'logo_path': None, 'name': 'Wolper Organization', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-10-03', 'revenue': 0, 'runtime': 113, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Be careful what you invite inside.', 'title': "Salem's Lot", 'video': False, 'vote_average': 6.224, 'vote_count': 288}
# {'adult': False, 'backdrop_path': '/xKxNYp78qj682Q3zSOB7xbYq16D.jpg', 'belongs_to_collection': None, 'budget': 4400000, 'genres': [{'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}], 'homepage': '', 'id': 1064028, 'imdb_id': 'tt24871974', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Subservience', 'overview': "With his wife out sick, a struggling father brings home a lifelike AI, only to have his self-aware new help want everything her new family has to offer... Like the affection of her owner and she'll kill to get it.", 'popularity': 378.806, 'poster_path': '/gBenxR01Uy0Ev9RTIw6dVBPoyQU.jpg', 'production_companies': [{'id': 1020, 'logo_path': '/kuUIHNwMec4dwOLghDhhZJzHZTd.png', 'name': 'Millennium Media', 'origin_country': 'US'}, {'id': 48738, 'logo_path': None, 'name': 'Campbell Grobman Films', 'origin_country': 'US'}, {'id': 12142, 'logo_path': '/rPnEeMwxjI6rYMGqkWqIWwIJXxi.png', 'name': 'XYZ Films', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-15', 'revenue': 159422, 'runtime': 105, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': "Don't turn her on.", 'title': 'Subservience', 'video': False, 'vote_average': 6.7, 'vote_count': 193}
# {'adult': False, 'backdrop_path': '/hDXuagNP746lfYDcNT0GkKHvQzA.jpg', 'belongs_to_collection': None, 'budget': 10000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://neonrated.com/films/longlegs', 'id': 1226578, 'imdb_id': 'tt23468450', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Longlegs', 'overview': 'FBI Agent Lee Harker is assigned to an unsolved serial killer case that takes an unexpected turn, revealing evidence of the occult. Harker discovers a personal connection to the killer and must stop him before he strikes again.', 'popularity': 325.604, 'poster_path': '/5aj8vVGFwGVbQQs26ywhg4Zxk2L.jpg', 'production_companies': [{'id': 184518, 'logo_path': '/lOouI8ibBzhLI4qvku74FPUVT8t.png', 'name': 'C2 Motion Picture Group', 'origin_country': 'US'}, {'id': 831, 'logo_path': '/vLENXiYTyITnMDrTKabUXhgTKX2.png', 'name': 'Saturn Films', 'origin_country': 'US'}, {'id': 85465, 'logo_path': '/vWaAGbuCTIjEv8yz2Pog4Sfo67X.png', 'name': 'Oddfellows Entertainment', 'origin_country': 'CA'}, {'id': 232289, 'logo_path': None, 'name': 'Traffic.', 'origin_country': 'US'}, {'id': 167684, 'logo_path': '/kzQwU2H6woBFti9cqjr9BrVXrst.png', 'name': 'Range Media Partners', 'origin_country': 'US'}, {'id': 22842, 'logo_path': '/waIZoO3pnB0VVCUVo8u6hqcYN9U.png', 'name': 'Waypoint Entertainment', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-05-31', 'revenue': 102469694, 'runtime': 101, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Say your prayers.', 'title': 'Longlegs', 'video': False, 'vote_average': 6.7, 'vote_count': 1083}
# {'adult': False, 'backdrop_path': '/9juRmk8QjcsUcbrevVu5t8VZy5G.jpg', 'belongs_to_collection': None, 'budget': 38400000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 80, 'name': 'Crime'}, {'id': 53, 'name': 'Thriller'}], 'homepage': '', 'id': 923667, 'imdb_id': 'tt20316748', 'origin_country': ['CN', 'HK'], 'original_language': 'cn', 'original_title': '九龍城寨之圍城', 'overview': 'In 1980s Hong Kong, troubled youth Chan Lok-kwun, a mainland refugee, struggles to survive in the Kowloon Walled City by joining underground fights. Betrayed by crime boss Mr. Big while trying to buy a fake ID, he steals drugs from him and seeks refuge in the Walled City, where he encounters Cyclone, a compassionate yet authoritative crime lord.', 'popularity': 287.643, 'poster_path': '/h0tunBO4tMjvKVVG7fXqHgwOr5C.jpg', 'production_companies': [{'id': 62894, 'logo_path': '/fIu9uAhKFyEZipwObaA9EjQJsS2.png', 'name': 'Entertaining Power', 'origin_country': 'HK'}, {'id': 69437, 'logo_path': None, 'name': 'One Cool Pictures', 'origin_country': 'HK'}, {'id': 5686, 'logo_path': '/o4aETXAP9HxOSRbGDWgBfkSzSJw.png', 'name': 'Sil-Metropole Organisation', 'origin_country': 'HK'}, {'id': 214726, 'logo_path': None, 'name': 'HG Entertainment', 'origin_country': 'CN'}, {'id': 197030, 'logo_path': '/z9xtT1e3HunOnZUm3uGYb59eL7v.png', 'name': 'Tao Piao Piao', 'origin_country': 'CN'}, {'id': 5552, 'logo_path': '/wdtjT9x5OG7nLusPctACI3i7Im2.png', 'name': 'Media Asia Films', 'origin_country': 'HK'}, {'id': 131587, 'logo_path': '/vtQSkfAuPHoBtlEbUpsjs5kVfG6.png', 'name': 'Lian Ray Pictures', 'origin_country': 'CN'}], 'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_3166_1': 'HK', 'name': 'Hong Kong'}], 'release_date': '2024-04-23', 'revenue': 95335412, 'runtime': 125, 'spoken_languages': [{'english_name': 'Cantonese', 'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}], 'status': 'Released', 'tagline': "Don't cause trouble in the Walled City.", 'title': 'Twilight of the Warriors: Walled In', 'video': False, 'vote_average': 6.5, 'vote_count': 190}
# {'adult': False, 'backdrop_path': '/h9YlRHAZWOWtGonllmj6JJg1FrE.jpg', 'belongs_to_collection': None, 'budget': 25600000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}], 'homepage': 'http://www.dragonkeepermovie.com', 'id': 588648, 'imdb_id': 'tt7093904', 'origin_country': ['CN', 'ES'], 'original_language': 'zh', 'original_title': 'Dragonkeeper', 'overview': 'Set in Han Imperial China, the plot follows the adventures of enslaved girl Ping with ancient dragon Long Danzi. Dragons had been banished from the kingdom. Ping, an orphan, finds one of the last remaining dragon eggs. Palace guards force Ping to run away in order to return the dragon egg to the ocean and save all dragons from extinction. Ping discovers that she is a true Dragonkeeper.', 'popularity': 338.237, 'poster_path': '/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg', 'production_companies': [{'id': 67412, 'logo_path': '/vgVqq5hunVs8GN5Je9d9rG7Q2NU.png', 'name': 'Movistar+', 'origin_country': 'ES'}, {'id': 29566, 'logo_path': '/wHbtRtUnXGNzX0riQIpq1fcgueq.png', 'name': 'Atresmedia', 'origin_country': 'ES'}, {'id': 115983, 'logo_path': None, 'name': 'China Film Animation', 'origin_country': 'CN'}, {'id': 222691, 'logo_path': None, 'name': 'Guardián de Dragones AIE', 'origin_country': ''}, {'id': 202198, 'logo_path': None, 'name': 'Telefonica', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_3166_1': 'ES', 'name': 'Spain'}], 'release_date': '2024-04-11', 'revenue': 5427272, 'runtime': 99, 'spoken_languages': [{'english_name': 'Mandarin', 'iso_639_1': 'zh', 'name': '普通话'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'status': 'Released', 'tagline': 'Everybody just saw a girl.', 'title': 'Dragonkeeper', 'video': False, 'vote_average': 7.3, 'vote_count': 113}
# {'adult': False, 'backdrop_path': '/sjC29cgm4qZAnpOJQbYKCxDCcra.jpg', 'belongs_to_collection': None, 'budget': 12000000, 'genres': [{'id': 27, 'name': 'Horror'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 53, 'name': 'Thriller'}], 'homepage': 'https://afraid.movie', 'id': 1062215, 'imdb_id': 'tt24577462', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'Afraid', 'overview': "Curtis Pike and his family are selected to test a new home device: a digital assistant called AIA. AIA observes the family's behaviors and begins to anticipate their needs. And she can – and will – make sure nothing – and no one – gets in her family's way.", 'popularity': 253.566, 'poster_path': '/y1oqFJPAYu7qLMz9Rv1FBoDboff.jpg', 'production_companies': [{'id': 3172, 'logo_path': '/rzKluDcRkIwHZK2pHsiT667A2Kw.png', 'name': 'Blumhouse Productions', 'origin_country': 'US'}, {'id': 1473, 'logo_path': None, 'name': 'Depth of Field', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-08-28', 'revenue': 12567788, 'runtime': 84, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Be careful what you let in.', 'title': 'Afraid', 'video': False, 'vote_average': 6.2, 'vote_count': 222}
# {'adult': False, 'backdrop_path': '/AjTodtZJlQxycfRPktnUTpknblv.jpg', 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}], 'homepage': 'https://gracieandpedro.com/', 'id': 1207830, 'imdb_id': 'tt29258548', 'origin_country': ['CA'], 'original_language': 'en', 'original_title': 'Gracie & Pedro: Pets to the Rescue', 'overview': 'Family frenemies, Gracie and Pedro, must put their differences aside, embarking on a thrilling quest packed with perilous escapades in order to reunite with their owners.', 'popularity': 289.478, 'poster_path': '/1agSI7NGvagr720za8XAubtqUoB.jpg', 'production_companies': [{'id': 213963, 'logo_path': None, 'name': 'Second Chance Productions', 'origin_country': ''}, {'id': 142108, 'logo_path': None, 'name': 'Luminescence', 'origin_country': 'HU'}, {'id': 133835, 'logo_path': None, 'name': 'GTE Productions', 'origin_country': ''}], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'ZA', 'name': 'South Africa'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2024-05-01', 'revenue': 664443, 'runtime': 89, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Unite like cats and dogs.', 'title': 'Gracie & Pedro: Pets to the Rescue', 'video': False, 'vote_average': 7.0, 'vote_count': 20}
# {'adult': False, 'backdrop_path': '/hd1TvTUGjkoYoqvXYfSBpI5Ri9B.jpg', 'belongs_to_collection': {'id': 1189668, 'name': 'My Hero Academia Collection', 'poster_path': '/xTlc93PezcZHMcvmAtPL3cyX0yE.jpg', 'backdrop_path': None}, 'budget': 0, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': '', 'id': 1159311, 'imdb_id': 'tt32176689', 'origin_country': ['JP'], 'original_language': 'ja', 'original_title': '僕のヒーローアカデミア THE MOVIE ユアネクスト', 'overview': "In a society devastated by the effects of an all-out war between heroes and villains, a mysterious giant fortress suddenly appears, engulfing towns and people one after another. Then, a man reminiscent of All Might, the 'symbol of peace', stands in front of Izuku and his friends...", 'popularity': 234.101, 'poster_path': '/8rdB1wkheEMMqcY8qLAKjCMPcnZ.jpg', 'production_companies': [{'id': 2849, 'logo_path': '/cN3JNIKawjOMtfk0GBVIbsx69bg.png', 'name': 'BONES', 'origin_country': 'JP'}, {'id': 882, 'logo_path': '/fRSWWjquvzcHjACbtF53utZFIll.png', 'name': 'TOHO', 'origin_country': 'JP'}], 'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}], 'release_date': '2024-08-02', 'revenue': 26622396, 'runtime': 110, 'spoken_languages': [{'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}], 'status': 'Released', 'tagline': 'A Challenge Against the Symbol of Peace. Heroes vs. Villains The Dawn of the Final Battle.', 'title': "My Hero Academia: You're Next", 'video': False, 'vote_average': 7.1, 'vote_count': 17}
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              58 non-null     bool
#  1   backdrop_path      58 non-null     object
#  2   genre_ids          58 non-null     object
#  3   id                 58 non-null     int64
#  4   original_language  58 non-null     object
#  5   original_title     58 non-null     object
#  6   overview           58 non-null     object
#  7   popularity         58 non-null     float64
#  8   poster_path        58 non-null     object
#  9   release_date       58 non-null     object
#  10  title              58 non-null     object
#  11  video              58 non-null     bool
#  12  vote_average       58 non-null     float64
#  13  vote_count         58 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 6.0+ KB
# None

# %%
fullConDf = pd.merge(ConDf, money, how="inner", on="id")

# %%
sns.regplot(data=fullConDf, x='budget', y='revenue')
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
fullConDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 57
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              58 non-null     bool
#  1   backdrop_path      58 non-null     object
#  2   genre_ids          58 non-null     object
#  3   id                 58 non-null     int64
#  4   original_language  58 non-null     object
#  5   original_title     58 non-null     object
#  6   overview           58 non-null     object
#  7   popularity         58 non-null     float64
#  8   poster_path        58 non-null     object
#  9   release_date       58 non-null     object
#  10  title              58 non-null     object
#  11  video              58 non-null     bool
#  12  vote_average       58 non-null     float64
#  13  vote_count         58 non-null     int64
#  14  budget             58 non-null     int64
#  15  revenue            58 non-null     int64
# dtypes: bool(2), float64(2), int64(4), object(8)
# memory usage: 6.9+ KB

# %%
import numpy as np
revenue_sqrt = np.sqrt(fullConDf["revenue"])
budget_sqrt = np.sqrt(fullConDf["budget"])

# %%
def get_best_fit(df, x, y):
    
    m = 0
    b = 0
    
    #Calculate Residuals
    res = 0
    for count in range(len(df)):
        m = m + 1
        b = 0
        
        res = 0
        
        for i in range(len(df)):
            pred_y = (m * df.loc[i][x]) + b
            act_y = df.loc[i][y]
            temp = act_y - pred_y
            temp = temp ** 2
            res = res + temp
        print(res)
    
    return(m, b, res)

# %%
get_best_fit(fullConDf, 'budget', 'revenue')
# Out:
# 7065403762572751423
# 5344142617328789426
# 4079459576484543431
# 3271354640040013438
# 2919827807995199447
# 3024879080350101458
# 3586508457104719471
# 4604715938259053486
# 6079501523813103503
# 8010865213766869522
# -8047937065589200073
# -5203417166836002050
# -1902319163683088025
# 1855356943869542002
# 6069611155821888031
# -7706300601535601554
# -2578890180783823521
# 3005098344367670514
# 9045664973918880551
# -2903934365839745026
# 4049788472510897015
# -6986654658448296558
# 880224388701777487
# 9203681540251567534
# C:\Users\lochoahernandez\AppData\Local\Temp\ipykernel_24172\3105876338.py:19: RuntimeWarning: overflow encountered in longlong_scalars
#   res = res + temp
# -463027277508478033
# 8773586082840744018
# 20033473880130455
# -8276941030680767106
# 2329406642867602951
# -5054411652893862606
# 6465092229453939455
# -5569857508094098
# -6019653840070411649
# 6869584355476538418
# 1768656581713652871
# -2875693087649516674
# -7063464652612970217
# 7652085960532843858
# 4377470604368822319
# 1559433352604516782
# -802025794760072753
# -2706906837724946286
# -4155209776290103817
# -5146934610455545346
# -5682081340221270873
# -5760649965587280398
# -5382640486553573921
# -4548052903120151442
# -3256887215287012961
# -1509143423054158478
# 695178473578412007
# 3356078474610698494
# 6473556580042700983
# -8399131283835132142
# -4368496969603697649
# 118715449027452846
# 5062505972058319343
# -7983869474220649774
# (58, 0, -7983869474220649774)

# %%
def determination(df, x, y):
    y_mean = df[y].mean()
    
    ss_total = ((df[y] - y_mean) ** 2).sum()
    
    x_mean = df[x].mean()
    slope = ((df[x] - x_mean) * (df[y] - y_mean)).sum() / ((df[x] - x_mean) ** 2).sum()
    intercept = y_mean - slope * x_mean
    
    y_pred = intercept + slope * df[x]
    
    ss_residual = ((df[y] - y_pred) ** 2).sum()
    
    r_squared = 1 - (ss_residual / ss_total)
    
    return r_squared

# %%
determination(fullConDf, 'budget', 'revenue')
# Out:
# 0.6005352291624959

# %%
fullConDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 57
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              58 non-null     bool
#  1   backdrop_path      58 non-null     object
#  2   genre_ids          58 non-null     object
#  3   id                 58 non-null     int64
#  4   original_language  58 non-null     object
#  5   original_title     58 non-null     object
#  6   overview           58 non-null     object
#  7   popularity         58 non-null     float64
#  8   poster_path        58 non-null     object
#  9   release_date       58 non-null     object
#  10  title              58 non-null     object
#  11  video              58 non-null     bool
#  12  vote_average       58 non-null     float64
#  13  vote_count         58 non-null     int64
#  14  budget             58 non-null     int64
#  15  revenue            58 non-null     int64
# dtypes: bool(2), float64(2), int64(4), object(8)
# memory usage: 9.0+ KB
