# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_json('games.json')
data.head(50)
# Out:
#          ID                                       name  release_date  \
# 0     20200                           Galactic Bowling  Oct 21, 2008
# 1    655370                               Train Bandit  Oct 12, 2017
# 2   1732930                               Jolt Project  Nov 17, 2021
# 3   1355720                                   Henosis™  Jul 23, 2020
# 4   1139950                      Two Weeks in Painland   Feb 3, 2020
# 5   1469160                             Wartune Reborn  Feb 26, 2021
# 6   1659180                                  TD Worlds   Jan 9, 2022
# 7   1968760         Legend of Rome - The Wrath of Mars   May 5, 2022
# 8   1178150                      MazM: Jekyll and Hyde   Apr 2, 2020
# 9    320150                  Deadlings: Rotten Edition  Nov 11, 2014
# 10  1026420                                     WARSAW   Oct 2, 2019
# 11   485000                             Cthulhu Realms   Jul 1, 2016
# 12  1620060                          Clockwork Dungeon  Aug 27, 2021
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97410 entries, 0 to 97409
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        97410 non-null  int64
#  1   name                      97404 non-null  object
#  2   release_date              97410 non-null  object
#  3   estimated_owners          97410 non-null  object
#  4   peak_ccu                  97410 non-null  int64
#  5   required_age              97410 non-null  int64
#  6   price                     97410 non-null  float64
#  7   dlc_count                 97410 non-null  int64
#  8   main_description          92540 non-null  object
#  9   supported_languages       97410 non-null  object
#  10  full_audio_languages      97410 non-null  object
#  11  reviews                   10125 non-null  object
#  12  header_image              97410 non-null  object
# ...

# %%
filtered_data = data.loc[data["name"].str.contains("Call of Duty", na=False)]
print(filtered_data)
# Out:
#             ID                                              name  \
# 136       7940                  Call of Duty® 4: Modern Warfare®
# 3073     42710                          Call of Duty®: Black Ops
# 7629    393080         Call of Duty®: Modern Warfare® Remastered
# 8176    202990                       Call of Duty®: Black Ops II
# 15118   311210                      Call of Duty®: Black Ops III
# 16436   209160                             Call of Duty®: Ghosts
# 20805     2640                    Call of Duty: United Offensive
# 21930   209650    Call of Duty®: Advanced Warfare - Gold Edition
# 22085   209660    Call of Duty®: Advanced Warfare - Gold Edition
# 24094   476600                               Call of Duty®: WWII
# 27498    10090                        Call of Duty: World at War
# 29125    42680                  Call of Duty®: Modern Warfare® 3
# 29670    42700                          Call of Duty®: Black Ops
# ...

# %%
filtered_datav = data.loc[data["name"].str.contains("Insurgency", na=False)]
print(filtered_datav)
# Out:
#             ID                              name  release_date  \
# 1893    581320             Insurgency: Sandstorm  Dec 12, 2018
# 10405   222880                        Insurgency  Jan 22, 2014
# 81790  2479900                 Insurgency Runner  Sep 15, 2023
# 94631  2812380  Burkina Faso: Radical Insurgency   Jul 9, 2024
#
#         estimated_owners  peak_ccu  required_age  price  dlc_count  \
# 1893   2000000 - 5000000      3203            17  14.99          0
# 10405  2000000 - 5000000       567             0  14.99          0
# 81790          0 - 20000         0             0   4.99          0
# 94631          0 - 20000         0             0   9.99          0
#
#                                         main_description  \
# 1893   Insurgency: Sandstorm is a team-based, tactica...
# 10405  Take to the streets for intense close quarters...
# 81790  Into the desert, in a remote city captured by ...
# 94631  Features : - 6 Missions - 12 Weapons - Operati...
#
# ...

# %%
data.loc[data['ID'] == 35001]
# Out:
# Empty DataFrame
# Columns: [ID, name, release_date, estimated_owners, peak_ccu, required_age, price, dlc_count, main_description, supported_languages, full_audio_languages, reviews, header_image, website, support_url, support_email, windows, mac, linux, metacritic_score, metacriticURL, user_score, positive, negative, score_rank, achievements, recommendations, notes, average_playtime_forever, average_playtime_2weeks, median_playtime_forever, packages, developers, publishers, categories, genres, tags, screenshots]
# Index: []
#
# [0 rows x 38 columns]

# %%
data[data["ID"] == 22380]
# Out:
#          ID                name  release_date   estimated_owners  peak_ccu  \
# 1025  22380  Fallout: New Vegas  Oct 19, 2010  2000000 - 5000000      5776
#
#       required_age  price  dlc_count  \
# 1025            16   9.99          0
#
#                                        main_description  \
# 1025  Welcome to Vegas. New Vegas. It’s the kind of ...
#
#                                     supported_languages  ...  \
# 1025  ['English', 'French', 'German', 'Italian', 'Sp...  ...
#
#      average_playtime_forever average_playtime_2weeks median_playtime_forever  \
# 1025                     3044                     112                     976
#
#      packages              developers          publishers  \
# 1025      153  Obsidian Entertainment  Bethesda Softworks
#
#                                              categories      genres  \
# 1025  Single-player,Steam Achievements,Partial Contr...  Action,RPG
#
#                                                    tags  \
# ...

# %% [markdown]
# *** The game with id 22890 is Fallout:New Vegas. It was released on Oct 19, 2010 by Obsidian Entertainment under Bethesda Softworks ***

# %%
data.loc[data["ID"] == 252490, 'main_description']
# Out:
# 35001    The only aim in Rust is to survive. Everything...
# Name: main_description, dtype: object

# %%
outliers = data.loc[data["price"] >= 950]
# Out:
#             ID                                name  release_date  \
# 26936  1200520   Ascent Free-Roaming VR Experience  Dec 27, 2019
# 81901  2499620                   The Leverage Game  Aug 25, 2023
# 82971  2504210  The Leverage Game Business Edition  Aug 26, 2023
#
#       estimated_owners  peak_ccu  required_age   price  dlc_count  \
# 26936        0 - 20000         0             0  999.00          0
# 81901        0 - 20000         0             0  999.98          0
# 82971        0 - 20000         0             0  999.98          0
#
#                                         main_description  \
# 26936  The Ascent is a Free-Roaming highly immersive ...
# 81901  The Leverage Game is a board game in which pla...
# 82971  The Leverage Game is a board game in which pla...
#
#            supported_languages  ... average_playtime_forever  \
# 26936              ['English']  ...                        0
# 81901  ['English', 'Japanese']  ...                        0
# ...

# %%
data.loc[data["recommendations"] >= 3441592]
# Out:
#         ID                              name  release_date  \
# 46158  730  Counter-Strike: Global Offensive  Aug 21, 2012
#
#            estimated_owners  peak_ccu  required_age  price  dlc_count  \
# 46158  50000000 - 100000000    825215             0    0.0          0
#
#                                         main_description  \
# 46158  Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                      supported_languages  ...  \
# 46158  ['Czech', 'Danish', 'Dutch', 'English', 'Finni...  ...
#
#       average_playtime_forever average_playtime_2weeks  \
# 46158                    30484                     777
#
#       median_playtime_forever packages                       developers  \
# 46158                    6357      253  Valve,Hidden Path Entertainment
#
#       publishers                                         categories  \
# 46158      Valve  Multi-player,Steam Achievements,Full controlle...
#
# ...

# %%
sns.scatterplot(y='price', x='metacritic_score', data=data)
# Out:
# <AxesSubplot:xlabel='metacritic_score', ylabel='price'>

# %% [markdown]
# **There are a few outliers, esspecially towards the 0 metacritic range. It is likely that these games are prices outragiously high for a joke/meme, resulting in either no metacritic score being conducted, or only a poor one at that. Most games are prices reasonably, and are within the 60 to 95 range. The biggest outlier would be "The Leverage Game" on steam for 999.98 USD **

# %%
avgPrice = data["price"].mean()
print(avgPrice)
# Out:
# 7.08626157478198

# %%
sns.scatterplot(x='price', y='recommendations', data=data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='recommendations'>

# %%
'''def scatter(data, x, y, outliers):
    idx=[]
    for i in range(outliers):
        idx = data[x].idxmax()
    data.drop_idx([], inplace=True)
    
sns.scatterplot(data=data, x=x, y=y)
    '''
# Out:
# 'def scatter(data, x, y, outliers):\n    idx=[]\n    for i in range(outliers):\n        idx = data[x].idxmax()\n    data.drop_idx([], inplace=True)\n    \nsns.scatterplot(data=data, x=x, y=y)\n    '

# %%
# Index is 81901
# Index is 82971
# Index is 46158
# Index is 26936
cleanedDF = data.drop([81901, 82971, 46158, 26936])

# %%
sns.scatterplot(data=cleanedDF, x="price", y="recommendations")
# Out:
# <AxesSubplot:xlabel='price', ylabel='recommendations'>

# %%
cleanedDF[cleanedDF["price"] == cleanedDF["price"].max()]
# Out:
#             ID       name  release_date estimated_owners  peak_ccu  \
# 94022  3013840  True Love  Jun 27, 2024        0 - 20000         0
#
#        required_age  price  dlc_count  \
# 94022             0  500.0          0
#
#                                         main_description supported_languages  \
# 94022  This game created out of pure sadness. I have ...         ['English']
#
#        ... average_playtime_forever average_playtime_2weeks  \
# 94022  ...                        0                       0
#
#       median_playtime_forever packages developers          publishers  \
# 94022                       0        0      A Guy  Whoes heart broken
#
#                          categories                         genres  \
# 94022  Single-player,Family Sharing  Action,Adventure,Casual,Indie
#
#                                                     tags  \
# 94022  Casual,Action-Adventure,Visual Novel,Dating Si...
#
#                                              screenshots
# ...

# %%
data.corr(method='pearson')
# Out:
#                                 ID  peak_ccu  required_age     price  \
# ID                        1.000000 -0.008097     -0.103954 -0.066164
# peak_ccu                 -0.008097  1.000000      0.028416  0.040309
# required_age             -0.103954  0.028416      1.000000  0.094271
# price                    -0.066164  0.040309      0.094271  1.000000
# dlc_count                      NaN       NaN           NaN       NaN
# windows                   0.007552  0.000384     -0.006858 -0.015266
# mac                      -0.201905  0.002614     -0.002783  0.033587
# linux                    -0.139542  0.003509      0.001357  0.026972
# metacritic_score         -0.263051  0.038814      0.195588  0.135616
# user_score               -0.018262 -0.000429      0.079026 -0.000489
# positive                 -0.046919  0.469666      0.067499  0.029094
# negative                 -0.038944  0.397728      0.065021  0.024773
# score_rank                0.152725 -0.254030      0.079917  0.281748
# ...

# %%
plot = sns.scatterplot(data=data, x='positive', y='negative')
# Out:
# <AxesSubplot:xlabel='positive', ylabel='negative'>

# %%
data['negative'].corr(data['positive'])
# Out:
# 0.7823842565518223

# %%
sns.scatterplot(data=data, x='achievements', y='user_score')
# Out:
# <AxesSubplot:xlabel='achievements', ylabel='user_score'>
